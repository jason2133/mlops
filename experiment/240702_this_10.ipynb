# %%
# !nvidia-smi
# Out:
# Tue Jul  2 17:21:07 2024
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 551.23                 Driver Version: 551.23         CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                     TCC/WDDM  | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 2080 ...  WDDM  |   00000000:01:00.0  On |                  N/A |
# |  0%   41C    P8              8W /  280W |     290MiB /   8192MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# +-----------------------------------------------------------------------------------------+

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import signal
from sklearn.model_selection import train_test_split,StratifiedKFold
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import classification_report,accuracy_score,ConfusionMatrixDisplay,confusion_matrix,precision_score,recall_score,roc_curve,roc_auc_score,balanced_accuracy_score
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from xgboost import XGBClassifier
import datetime
from dataclasses import dataclass
from statsmodels.tsa.holtwinters import SimpleExpSmoothing
from scipy.ndimage import gaussian_filter1d
from itertools import combinations as comb
from pyts.image import RecurrencePlot
import PIL
from sklearn.utils import class_weight
from sklearn.model_selection import RandomizedSearchCV,GridSearchCV,StratifiedKFold
from unidecode import unidecode

# %%
train_data = pd.read_csv('./dataset/dataset_1/train_motion_data.csv')
test_data = pd.read_csv('./dataset/dataset_1/test_motion_data.csv')
print(train_data.shape)
print(test_data.shape)
# Out:
# (3644, 8)
# (3084, 8)

# %%
train_data.head()
# Out:
#        AccX      AccY      AccZ     GyroX     GyroY     GyroZ   Class  \
# 0  0.000000  0.000000  0.000000  0.059407 -0.174707  0.101938  NORMAL
# 1 -1.624864 -1.082492 -0.204183 -0.028558  0.051313  0.135536  NORMAL
# 2 -0.594660 -0.122410  0.220502 -0.019395 -0.029322  0.087888  NORMAL
# 3  0.738478 -0.228456  0.667732  0.069791 -0.029932  0.054902  NORMAL
# 4  0.101741  0.777568 -0.066730  0.030696 -0.003665  0.054902  NORMAL
#
#    Timestamp
# 0    3581629
# 1    3581630
# 2    3581630
# 3    3581631
# 4    3581631

# %%
print(train_data['Class'].value_counts())
# Out:
# SLOW          1331
# NORMAL        1200
# AGGRESSIVE    1113
# Name: Class, dtype: int64

# %%
print(test_data['Class'].value_counts())
# Out:
# SLOW          1273
# NORMAL         997
# AGGRESSIVE     814
# Name: Class, dtype: int64

# %%
print(len(train_data))
# Out:
# 3644

# %%
train_data['Timestamp'] = np.arange(3644)

# %%
test_data.head()
# Out:
#        AccX      AccY      AccZ     GyroX     GyroY     GyroZ  Class  \
# 0  0.758194 -0.217791  0.457263  0.000000  0.000000  0.000000      1
# 1  0.667560 -0.038610  0.231416 -0.054367 -0.007712  0.225257      1
# 2  2.724449 -7.584121  2.390926  0.023824  0.013668 -0.038026      1
# 3  2.330950 -7.621754  2.529024  0.056810 -0.180587 -0.052076      1
# 4  2.847215 -6.755621  2.224640 -0.031765 -0.035201  0.035277      1
#
#    Timestamp
# 0     818922
# 1     818923
# 2     818923
# 3     818924
# 4     818924

# %%
test_data.tail()
# Out:
#           AccX      AccY      AccZ     GyroX     GyroY     GyroZ  Class  \
# 3079 -0.713858 -0.652975 -0.164015 -0.147829 -1.309466  0.517250      3
# 3080  1.514261  0.330070  1.020714  1.321302  1.707598 -0.674548      3
# 3081  1.280216 -1.735172 -2.332695  0.583376  0.690507 -0.468075      3
# 3082  0.912313  0.583314 -0.965622  0.235794  0.512745  0.406073      3
# 3083  1.462172  0.190287  0.019377 -0.254731 -0.279547  0.076205      3
#
#       Timestamp
# 3079     820706
# 3080     820707
# 3081     820707
# 3082     820708
# 3083     820709

# %%
print(len(test_data))
# Out:
# 3084

# %%
test_data['Timestamp'] = np.arange(3084)

# %%
x_train = train_data[['AccX', 'AccY', 'AccZ', 'GyroX', 'GyroY', 'GyroZ', 'Timestamp']]
train_data.Class=train_data.Class.replace(['AGGRESSIVE', 'NORMAL', 'SLOW'],[1,2,3])
y_train = train_data[['Class']]

# %%
x_test = test_data[['AccX', 'AccY', 'AccZ', 'GyroX', 'GyroY', 'GyroZ', 'Timestamp']]
test_data.Class=test_data.Class.replace(['AGGRESSIVE', 'NORMAL', 'SLOW'],[1,2,3])
y_test = test_data[['Class']]

# %%
x_train.head()
# Out:
#        AccX      AccY      AccZ     GyroX     GyroY     GyroZ  Timestamp
# 0  0.000000  0.000000  0.000000  0.059407 -0.174707  0.101938          0
# 1 -1.624864 -1.082492 -0.204183 -0.028558  0.051313  0.135536          1
# 2 -0.594660 -0.122410  0.220502 -0.019395 -0.029322  0.087888          2
# 3  0.738478 -0.228456  0.667732  0.069791 -0.029932  0.054902          3
# 4  0.101741  0.777568 -0.066730  0.030696 -0.003665  0.054902          4

# %%
# Acceleration Magnitude 계산
x_train['AccMagnitude'] = np.sqrt(x_train['AccX']**2 + x_train['AccY']**2 + x_train['AccZ']**2)
# Rotation Magnitude 계산
x_train['GyroMagnitude'] = np.sqrt(x_train['GyroX']**2 + x_train['GyroY']**2 + x_train['GyroZ']**2)
# Jerk 계산
x_train['JerkX'] = x_train['AccX'].diff().div(x_train['Timestamp'].diff(), fill_value=0)
x_train['JerkY'] = x_train['AccY'].diff().div(x_train['Timestamp'].diff(), fill_value=0)
x_train['JerkZ'] = x_train['AccZ'].diff().div(x_train['Timestamp'].diff(), fill_value=0)
x_train['JerkMagnitude'] = np.sqrt(x_train['JerkX']**2 + x_train['JerkY']**2 + x_train['JerkZ']**2)

# %%
# Acceleration Magnitude 계산
x_test['AccMagnitude'] = np.sqrt(x_test['AccX']**2 + x_test['AccY']**2 + x_test['AccZ']**2)
# Rotation Magnitude 계산
x_test['GyroMagnitude'] = np.sqrt(x_test['GyroX']**2 + x_test['GyroY']**2 + x_test['GyroZ']**2)
# Jerk 계산
x_test['JerkX'] = x_test['AccX'].diff().div(x_test['Timestamp'].diff(), fill_value=0)
x_test['JerkY'] = x_test['AccY'].diff().div(x_test['Timestamp'].diff(), fill_value=0)
x_test['JerkZ'] = x_test['AccZ'].diff().div(x_test['Timestamp'].diff(), fill_value=0)
x_test['JerkMagnitude'] = np.sqrt(x_test['JerkX']**2 + x_test['JerkY']**2 + x_test['JerkZ']**2)

# %%
x_train.head()
# Out:
#        AccX      AccY      AccZ     GyroX     GyroY     GyroZ  Timestamp  \
# 0  0.000000  0.000000  0.000000  0.059407 -0.174707  0.101938          0
# 1 -1.624864 -1.082492 -0.204183 -0.028558  0.051313  0.135536          1
# 2 -0.594660 -0.122410  0.220502 -0.019395 -0.029322  0.087888          2
# 3  0.738478 -0.228456  0.667732  0.069791 -0.029932  0.054902          3
# 4  0.101741  0.777568 -0.066730  0.030696 -0.003665  0.054902          4
#
#    AccMagnitude  GyroMagnitude     JerkX     JerkY     JerkZ  JerkMagnitude
# 0      0.000000       0.210816       NaN       NaN       NaN            NaN
# 1      1.963075       0.147711 -1.624864 -1.082492 -0.204183       1.963075
# 2      0.645930       0.094659  1.030204  0.960082  0.424685       1.470862
# 3      1.021474       0.093707  1.333138 -0.106046  0.447230       1.410148
# 4      0.787030       0.063007 -0.636737  1.006023 -0.734462       1.398911

# %%
x_train.isnull().sum()
# Out:
# AccX             0
# AccY             0
# AccZ             0
# GyroX            0
# GyroY            0
# GyroZ            0
# Timestamp        0
# AccMagnitude     0
# GyroMagnitude    0
# JerkX            1
# JerkY            1
# JerkZ            1
# JerkMagnitude    1
# dtype: int64

# %%
print(x_train.shape)
# Out:
# (3644, 13)

# %%
x_train.head()
# Out:
#        AccX      AccY      AccZ     GyroX     GyroY     GyroZ  Timestamp  \
# 0  0.000000  0.000000  0.000000  0.059407 -0.174707  0.101938          0
# 1 -1.624864 -1.082492 -0.204183 -0.028558  0.051313  0.135536          1
# 2 -0.594660 -0.122410  0.220502 -0.019395 -0.029322  0.087888          2
# 3  0.738478 -0.228456  0.667732  0.069791 -0.029932  0.054902          3
# 4  0.101741  0.777568 -0.066730  0.030696 -0.003665  0.054902          4
#
#    AccMagnitude  GyroMagnitude     JerkX     JerkY     JerkZ  JerkMagnitude
# 0      0.000000       0.210816       NaN       NaN       NaN            NaN
# 1      1.963075       0.147711 -1.624864 -1.082492 -0.204183       1.963075
# 2      0.645930       0.094659  1.030204  0.960082  0.424685       1.470862
# 3      1.021474       0.093707  1.333138 -0.106046  0.447230       1.410148
# 4      0.787030       0.063007 -0.636737  1.006023 -0.734462       1.398911

# %%
x_train_dropna = x_train.dropna()

# %%
print(x_train_dropna.shape)
# Out:
# (3643, 13)

# %%
x_train_dropna.head()
# Out:
#        AccX      AccY      AccZ     GyroX     GyroY     GyroZ  Timestamp  \
# 1 -1.624864 -1.082492 -0.204183 -0.028558  0.051313  0.135536          1
# 2 -0.594660 -0.122410  0.220502 -0.019395 -0.029322  0.087888          2
# 3  0.738478 -0.228456  0.667732  0.069791 -0.029932  0.054902          3
# 4  0.101741  0.777568 -0.066730  0.030696 -0.003665  0.054902          4
# 5  0.158470  0.345891  0.355274  0.021533  0.115454  0.014584          5
#
#    AccMagnitude  GyroMagnitude     JerkX     JerkY     JerkZ  JerkMagnitude
# 1      1.963075       0.147711 -1.624864 -1.082492 -0.204183       1.963075
# 2      0.645930       0.094659  1.030204  0.960082  0.424685       1.470862
# 3      1.021474       0.093707  1.333138 -0.106046  0.447230       1.410148
# 4      0.787030       0.063007 -0.636737  1.006023 -0.734462       1.398911
# 5      0.520551       0.118346  0.056728 -0.431676  0.422004       0.606341

# %%
y_train_dropna = y_train[1:]
print(len(y_train_dropna))
# Out:
# 3643

# %%
print(x_train_dropna.columns)
# Out:
# Index(['AccX', 'AccY', 'AccZ', 'GyroX', 'GyroY', 'GyroZ', 'Timestamp',
#        'AccMagnitude', 'GyroMagnitude', 'JerkX', 'JerkY', 'JerkZ',
#        'JerkMagnitude'],
#       dtype='object')

# %%
X_train = x_train_dropna[['AccX', 'AccY', 'AccZ', 'GyroX', 'GyroY', 'GyroZ',
       'AccMagnitude', 'GyroMagnitude', 'JerkX', 'JerkY', 'JerkZ',
       'JerkMagnitude']]

# %%
x_test.head()
# Out:
#        AccX      AccY      AccZ     GyroX     GyroY     GyroZ  Timestamp  \
# 0  0.758194 -0.217791  0.457263  0.000000  0.000000  0.000000          0
# 1  0.667560 -0.038610  0.231416 -0.054367 -0.007712  0.225257          1
# 2  2.724449 -7.584121  2.390926  0.023824  0.013668 -0.038026          2
# 3  2.330950 -7.621754  2.529024  0.056810 -0.180587 -0.052076          3
# 4  2.847215 -6.755621  2.224640 -0.031765 -0.035201  0.035277          4
#
#    AccMagnitude  GyroMagnitude     JerkX     JerkY     JerkZ  JerkMagnitude
# 0      0.911801       0.000000       NaN       NaN       NaN            NaN
# 1      0.707588       0.231853 -0.090634  0.179180 -0.225848       0.302204
# 2      8.405834       0.046908  2.056889 -7.545510  2.159510       8.113508
# 3      8.361843       0.196344 -0.393499 -0.037633  0.138098       0.418723
# 4      7.661206       0.059098  0.516265  0.866132 -0.304384       1.053264

# %%
x_test.isna().sum()
# Out:
# AccX             0
# AccY             0
# AccZ             0
# GyroX            0
# GyroY            0
# GyroZ            0
# Timestamp        0
# AccMagnitude     0
# GyroMagnitude    0
# JerkX            1
# JerkY            1
# JerkZ            1
# JerkMagnitude    1
# dtype: int64

# %%
x_test_dropna = x_test.dropna()

# %%
y_test_dropna = y_test[1:]
print(len(y_test_dropna))
# Out:
# 3083

# %%
X_test = x_test_dropna[['AccX', 'AccY', 'AccZ', 'GyroX', 'GyroY', 'GyroZ',
       'AccMagnitude', 'GyroMagnitude', 'JerkX', 'JerkY', 'JerkZ',
       'JerkMagnitude']]

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (3643, 12)
# (3083, 12)

# %%
rf = RandomForestClassifier()
rf.fit(X_train, y_train_dropna)
# Out:
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\ipykernel_launcher.py:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# RandomForestClassifier()

# %%
# rf.score(x_test, y_test)
y_pred = rf.predict(X_test)
print(accuracy_score(y_pred, y_test_dropna))
print(classification_report(y_pred, y_test_dropna, digits=4))
# Out:
# 0.4278300356795329
#               precision    recall  f1-score   support
#
#            1     0.4637    0.4323    0.4475       872
#            2     0.2768    0.3255    0.2992       848
#            3     0.5232    0.4886    0.5053      1363
#
#     accuracy                         0.4278      3083
#    macro avg     0.4212    0.4155    0.4173      3083
# weighted avg     0.4386    0.4278    0.4323      3083

# %%
X_train = X_train
y_train = y_train_dropna
X_test = X_test
y_test = y_test_dropna

# %%
print(X_test.shape)
print(y_test.shape)
# Out:
# (3083, 12)
# (3083, 1)

# %%
from sklearn.linear_model import LogisticRegression
Logit = LogisticRegression(C=1e2,
                          multi_class='ovr',
                          random_state=17,
                          max_iter=200
                          )
Logit.fit(X_train, y_train)
# Out:
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression(C=100.0, max_iter=200, multi_class='ovr', random_state=17)

# %%
y_test_pred = Logit.predict(X_test)
y_test_pred_proba = Logit.predict_proba(X_test)
print(y_test_pred[:5])
print(y_test_pred_proba[:5])
# Out:
# [3 1 1 1 1]
# [[0.27857099 0.31750994 0.40391907]
#  [0.92777752 0.05854834 0.01367415]
#  [0.95809564 0.02493519 0.01696917]
#  [0.94754099 0.03085346 0.02160555]
#  [0.58460732 0.20049567 0.21489701]]

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

print(accuracy_score(y_test, y_test_pred))
print(confusion_matrix(y_test, y_test_pred))
print(classification_report(y_test, y_test_pred, digits=4))
# Out:
# 0.4641582873824197
# [[376  52 385]
#  [289  70 638]
#  [212  76 985]]
#               precision    recall  f1-score   support
#
#            1     0.4287    0.4625    0.4450       813
#            2     0.3535    0.0702    0.1172       997
#            3     0.4905    0.7738    0.6004      1273
#
#     accuracy                         0.4642      3083
#    macro avg     0.4243    0.4355    0.3875      3083
# weighted avg     0.4299    0.4642    0.4031      3083

# %%
### 3. MLP Classifier

from sklearn.neural_network import MLPClassifier
clf = MLPClassifier(random_state=17, max_iter=1000).fit(X_train, y_train)
# Out:
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:1109: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
y_test_pred = clf.predict(X_test)
print(accuracy_score(y_test, y_test_pred))
print(confusion_matrix(y_test, y_test_pred))
print(classification_report(y_test, y_test_pred, digits=4))
# Out:
# 0.4459941615309763
# [[387 146 280]
#  [262 202 533]
#  [218 269 786]]
#               precision    recall  f1-score   support
#
#            1     0.4464    0.4760    0.4607       813
#            2     0.3274    0.2026    0.2503       997
#            3     0.4916    0.6174    0.5474      1273
#
#     accuracy                         0.4460      3083
#    macro avg     0.4218    0.4320    0.4195      3083
# weighted avg     0.4266    0.4460    0.4284      3083

# %%
### 4. KNN

from sklearn.neighbors import KNeighborsClassifier

# 5개 근접한 이웃, 거리측정기준 : 유클리드
knn = KNeighborsClassifier(n_neighbors=5, p=2)

# Model Fitting 과정
knn.fit(X_train, y_train)
# Out:
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# KNeighborsClassifier()

# %%
y_test_pred = knn.predict(X_test)
print(accuracy_score(y_test, y_test_pred))
print(confusion_matrix(y_test, y_test_pred))
print(classification_report(y_test, y_test_pred, digits=4))
# Out:
# 0.3996107687317548
# [[375 220 218]
#  [302 369 326]
#  [298 487 488]]
#               precision    recall  f1-score   support
#
#            1     0.3846    0.4613    0.4195       813
#            2     0.3429    0.3701    0.3560       997
#            3     0.4729    0.3833    0.4234      1273
#
#     accuracy                         0.3996      3083
#    macro avg     0.4001    0.4049    0.3996      3083
# weighted avg     0.4076    0.3996    0.4006      3083

# %%
### 5. Random Forest

from sklearn.ensemble import RandomForestClassifier

rf_model = RandomForestClassifier(n_estimators=5, random_state=17)
rf_model.fit(X_train, y_train)
# Out:
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\ipykernel_launcher.py:6: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# RandomForestClassifier(n_estimators=5, random_state=17)

# %%
y_test_pred = rf_model.predict(X_test)
print(accuracy_score(y_test, y_test_pred))
print(confusion_matrix(y_test, y_test_pred))
print(classification_report(y_test, y_test_pred, digits=4))
# Out:
# 0.3807979240999027
# [[418 225 170]
#  [407 322 268]
#  [419 420 434]]
#               precision    recall  f1-score   support
#
#            1     0.3360    0.5141    0.4064       813
#            2     0.3330    0.3230    0.3279       997
#            3     0.4977    0.3409    0.4047      1273
#
#     accuracy                         0.3808      3083
#    macro avg     0.3889    0.3927    0.3797      3083
# weighted avg     0.4018    0.3808    0.3803      3083

# %%
### 6. Decision Tree
from sklearn.tree import DecisionTreeClassifier
DT_MODEL= DecisionTreeClassifier(random_state=17)
DT_MODEL.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=17)

# %%
y_test_pred = DT_MODEL.predict(X_test)
print(accuracy_score(y_test, y_test_pred))
print(confusion_matrix(y_test, y_test_pred))
print(classification_report(y_test, y_test_pred, digits=4))
# Out:
# 0.3626337982484593
# [[318 240 255]
#  [335 323 339]
#  [351 445 477]]
#               precision    recall  f1-score   support
#
#            1     0.3167    0.3911    0.3500       813
#            2     0.3204    0.3240    0.3222       997
#            3     0.4454    0.3747    0.4070      1273
#
#     accuracy                         0.3626      3083
#    macro avg     0.3608    0.3633    0.3597      3083
# weighted avg     0.3710    0.3626    0.3645      3083

# %%
from xgboost import XGBClassifier
from xgboost import plot_importance
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import pandas as pd

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
y_train_xgb = le.fit_transform(y_train)
le = LabelEncoder()
y_test_xgb = le.fit_transform(y_test)
# Out:
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:115: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
xgb_class = XGBClassifier()
xgb_class.fit(X_train, y_train_xgb)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, objective='multi:softprob',
#               predictor='auto', random_state=0, reg_alpha=0, ...)

# %%
y_test_pred = xgb_class.predict(X_test)
print(accuracy_score(y_test_xgb, y_test_pred))
print(confusion_matrix(y_test_xgb, y_test_pred))
print(classification_report(y_test_xgb, y_test_pred, digits=4))
# Out:
# 0.42458644177748944
# [[365 205 243]
#  [274 309 414]
#  [228 410 635]]
#               precision    recall  f1-score   support
#
#            0     0.4210    0.4490    0.4345       813
#            1     0.3344    0.3099    0.3217       997
#            2     0.4915    0.4988    0.4951      1273
#
#     accuracy                         0.4246      3083
#    macro avg     0.4156    0.4192    0.4171      3083
# weighted avg     0.4221    0.4246    0.4231      3083

# %%
### 8. LightGBM
from lightgbm import LGBMClassifier
lgbm_class = LGBMClassifier()
lgbm_class.fit(X_train, y_train)
# Out:
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:98: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LGBMClassifier()

# %%
y_test_pred =lgbm_class.predict(X_test)
print(accuracy_score(y_test, y_test_pred))
print(confusion_matrix(y_test, y_test_pred))
print(classification_report(y_test, y_test_pred, digits=4))
# Out:
# 0.4388582549464807
# [[369 189 255]
#  [256 311 430]
#  [211 389 673]]
#               precision    recall  f1-score   support
#
#            1     0.4414    0.4539    0.4475       813
#            2     0.3498    0.3119    0.3298       997
#            3     0.4956    0.5287    0.5116      1273
#
#     accuracy                         0.4389      3083
#    macro avg     0.4289    0.4315    0.4296      3083
# weighted avg     0.4342    0.4389    0.4359      3083

# %%
# LightGBM Classifier 초기화
lgbm = LGBMClassifier()

# 하이퍼파라미터 그리드 설정
param_grid = {
    'num_leaves': [31, 50, 70],
    'learning_rate': [0.01, 0.05, 0.1],
    'n_estimators': [100, 200, 500],
    'max_depth': [5, 10, 15]
}

# GridSearchCV 설정
grid_search = GridSearchCV(estimator=lgbm, param_grid=param_grid, cv=5, scoring='accuracy', n_jobs=-1)

# 최적의 하이퍼파라미터 찾기
grid_search.fit(X_train, y_train)
# Out:
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:98: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GridSearchCV(cv=5, estimator=LGBMClassifier(), n_jobs=-1,
#              param_grid={'learning_rate': [0.01, 0.05, 0.1],
#                          'max_depth': [5, 10, 15],
#                          'n_estimators': [100, 200, 500],
#                          'num_leaves': [31, 50, 70]},
#              scoring='accuracy')

# %%
# 최적의 하이퍼파라미터 출력
print("최적의 하이퍼파라미터:")
print(grid_search.best_params_)

# 최적의 하이퍼파라미터로 모델 구축
best_lgbm = grid_search.best_estimator_

# 예측 수행
y_pred = best_lgbm.predict(X_test)
print(accuracy_score(y_test, y_test_pred))
print(confusion_matrix(y_test, y_test_pred))
print(classification_report(y_test, y_test_pred, digits=4))
# Out:
# 최적의 하이퍼파라미터:
# {'learning_rate': 0.01, 'max_depth': 15, 'n_estimators': 200, 'num_leaves': 31}
# 0.41809925397340253
# [[369 188 256]
#  [283 292 422]
#  [221 424 628]]
#               precision    recall  f1-score   support
#
#            1     0.4227    0.4539    0.4377       813
#            2     0.3230    0.2929    0.3072       997
#            3     0.4809    0.4933    0.4870      1273
#
#     accuracy                         0.4181      3083
#    macro avg     0.4088    0.4134    0.4106      3083
# weighted avg     0.4145    0.4181    0.4159      3083

# %%
from catboost import CatBoostClassifier
cat_class = CatBoostClassifier()
cat_class.fit(X_train, y_train)
# Out:
# Learning rate set to 0.08452
# 0:	learn: 1.0925967	total: 197ms	remaining: 3m 17s
# 1:	learn: 1.0873728	total: 218ms	remaining: 1m 48s
# 2:	learn: 1.0812067	total: 230ms	remaining: 1m 16s
# 3:	learn: 1.0748185	total: 252ms	remaining: 1m 2s
# 4:	learn: 1.0699077	total: 265ms	remaining: 52.7s
# 5:	learn: 1.0650078	total: 287ms	remaining: 47.6s
# 6:	learn: 1.0602734	total: 296ms	remaining: 42.1s
# 7:	learn: 1.0567353	total: 328ms	remaining: 40.6s
# 8:	learn: 1.0532127	total: 341ms	remaining: 37.6s
# 9:	learn: 1.0496693	total: 362ms	remaining: 35.8s
# 10:	learn: 1.0467705	total: 376ms	remaining: 33.8s
# 11:	learn: 1.0439706	total: 392ms	remaining: 32.2s
# 12:	learn: 1.0420513	total: 415ms	remaining: 31.5s
# 13:	learn: 1.0389289	total: 441ms	remaining: 31s
# 14:	learn: 1.0366549	total: 465ms	remaining: 30.5s
# 15:	learn: 1.0343264	total: 485ms	remaining: 29.8s
# 16:	learn: 1.0326218	total: 521ms	remaining: 30.1s
# 17:	learn: 1.0301050	total: 546ms	remaining: 29.8s
# 18:	learn: 1.0281033	total: 566ms	remaining: 29.2s
# 19:	learn: 1.0257434	total: 602ms	remaining: 29.5s
# 20:	learn: 1.0242303	total: 629ms	remaining: 29.3s
# 21:	learn: 1.0226588	total: 649ms	remaining: 28.8s
# 22:	learn: 1.0202739	total: 667ms	remaining: 28.3s
# 23:	learn: 1.0189222	total: 682ms	remaining: 27.7s
# 24:	learn: 1.0170462	total: 700ms	remaining: 27.3s
# 25:	learn: 1.0153931	total: 713ms	remaining: 26.7s
# 26:	learn: 1.0135853	total: 729ms	remaining: 26.3s
# 27:	learn: 1.0118983	total: 744ms	remaining: 25.8s
# 28:	learn: 1.0103467	total: 758ms	remaining: 25.4s
# 29:	learn: 1.0085088	total: 777ms	remaining: 25.1s
# 30:	learn: 1.0064675	total: 806ms	remaining: 25.2s
# 31:	learn: 1.0048876	total: 842ms	remaining: 25.5s
# 32:	learn: 1.0037938	total: 886ms	remaining: 26s
# 33:	learn: 1.0022719	total: 910ms	remaining: 25.9s
# 34:	learn: 0.9995186	total: 933ms	remaining: 25.7s
# 35:	learn: 0.9977894	total: 966ms	remaining: 25.9s
# 36:	learn: 0.9956416	total: 983ms	remaining: 25.6s
# 37:	learn: 0.9938614	total: 1.01s	remaining: 25.7s
# 38:	learn: 0.9922990	total: 1.04s	remaining: 25.6s
# 39:	learn: 0.9910961	total: 1.06s	remaining: 25.5s
# 40:	learn: 0.9895813	total: 1.08s	remaining: 25.3s
# 41:	learn: 0.9880137	total: 1.1s	remaining: 25.2s
# 42:	learn: 0.9868359	total: 1.12s	remaining: 24.9s
# 43:	learn: 0.9857792	total: 1.13s	remaining: 24.5s
# 44:	learn: 0.9847482	total: 1.14s	remaining: 24.2s
# 45:	learn: 0.9833830	total: 1.16s	remaining: 24s
# 46:	learn: 0.9819096	total: 1.17s	remaining: 23.8s
# 47:	learn: 0.9797427	total: 1.18s	remaining: 23.5s
# 48:	learn: 0.9780474	total: 1.19s	remaining: 23.2s
# 49:	learn: 0.9771262	total: 1.21s	remaining: 23s
# 50:	learn: 0.9758178	total: 1.22s	remaining: 22.7s
# 51:	learn: 0.9749060	total: 1.23s	remaining: 22.3s
# 52:	learn: 0.9734735	total: 1.24s	remaining: 22.1s
# 53:	learn: 0.9723099	total: 1.25s	remaining: 21.9s
# 54:	learn: 0.9712286	total: 1.26s	remaining: 21.6s
# 55:	learn: 0.9698927	total: 1.27s	remaining: 21.5s
# 56:	learn: 0.9683344	total: 1.29s	remaining: 21.3s
# 57:	learn: 0.9671842	total: 1.3s	remaining: 21.2s
# 58:	learn: 0.9658612	total: 1.32s	remaining: 21s
# 59:	learn: 0.9647592	total: 1.32s	remaining: 20.7s
# 60:	learn: 0.9634043	total: 1.33s	remaining: 20.5s
# 61:	learn: 0.9618440	total: 1.35s	remaining: 20.4s
# 62:	learn: 0.9603603	total: 1.35s	remaining: 20.1s
# 63:	learn: 0.9594377	total: 1.36s	remaining: 19.9s
# 64:	learn: 0.9585874	total: 1.38s	remaining: 19.8s
# 65:	learn: 0.9576531	total: 1.39s	remaining: 19.6s
# 66:	learn: 0.9570805	total: 1.4s	remaining: 19.5s
# 67:	learn: 0.9554163	total: 1.41s	remaining: 19.3s
# 68:	learn: 0.9545896	total: 1.41s	remaining: 19.1s
# 69:	learn: 0.9529694	total: 1.42s	remaining: 18.9s
# 70:	learn: 0.9520469	total: 1.45s	remaining: 19s
# 71:	learn: 0.9509991	total: 1.48s	remaining: 19.1s
# 72:	learn: 0.9497683	total: 1.49s	remaining: 19s
# 73:	learn: 0.9486045	total: 1.51s	remaining: 18.9s
# 74:	learn: 0.9472209	total: 1.52s	remaining: 18.7s
# 75:	learn: 0.9463239	total: 1.52s	remaining: 18.5s
# 76:	learn: 0.9449747	total: 1.54s	remaining: 18.4s
# 77:	learn: 0.9438249	total: 1.56s	remaining: 18.4s
# 78:	learn: 0.9424553	total: 1.56s	remaining: 18.2s
# 79:	learn: 0.9416721	total: 1.57s	remaining: 18s
# 80:	learn: 0.9409908	total: 1.57s	remaining: 17.8s
# 81:	learn: 0.9397863	total: 1.58s	remaining: 17.7s
# 82:	learn: 0.9386443	total: 1.58s	remaining: 17.5s
# 83:	learn: 0.9370243	total: 1.59s	remaining: 17.4s
# 84:	learn: 0.9359508	total: 1.6s	remaining: 17.2s
# 85:	learn: 0.9348707	total: 1.6s	remaining: 17s
# 86:	learn: 0.9335066	total: 1.61s	remaining: 16.9s
# 87:	learn: 0.9318401	total: 1.62s	remaining: 16.8s
# 88:	learn: 0.9305115	total: 1.62s	remaining: 16.6s
# 89:	learn: 0.9293010	total: 1.63s	remaining: 16.5s
# 90:	learn: 0.9280745	total: 1.64s	remaining: 16.3s
# 91:	learn: 0.9264342	total: 1.64s	remaining: 16.2s
# 92:	learn: 0.9250169	total: 1.65s	remaining: 16.1s
# 93:	learn: 0.9234790	total: 1.65s	remaining: 15.9s
# 94:	learn: 0.9226104	total: 1.67s	remaining: 15.9s
# 95:	learn: 0.9213972	total: 1.67s	remaining: 15.8s
# 96:	learn: 0.9199981	total: 1.68s	remaining: 15.6s
# 97:	learn: 0.9183871	total: 1.68s	remaining: 15.5s
# 98:	learn: 0.9173727	total: 1.69s	remaining: 15.4s
# 99:	learn: 0.9163262	total: 1.69s	remaining: 15.3s
# 100:	learn: 0.9150237	total: 1.7s	remaining: 15.1s
# 101:	learn: 0.9131977	total: 1.71s	remaining: 15s
# 102:	learn: 0.9122890	total: 1.71s	remaining: 14.9s
# 103:	learn: 0.9110046	total: 1.72s	remaining: 14.8s
# 104:	learn: 0.9096980	total: 1.72s	remaining: 14.7s
# 105:	learn: 0.9085150	total: 1.73s	remaining: 14.6s
# 106:	learn: 0.9076822	total: 1.73s	remaining: 14.4s
# 107:	learn: 0.9057940	total: 1.74s	remaining: 14.4s
# 108:	learn: 0.9042877	total: 1.75s	remaining: 14.3s
# 109:	learn: 0.9034546	total: 1.75s	remaining: 14.2s
# 110:	learn: 0.9024935	total: 1.75s	remaining: 14.1s
# 111:	learn: 0.9014933	total: 1.76s	remaining: 14s
# 112:	learn: 0.9009055	total: 1.76s	remaining: 13.8s
# 113:	learn: 0.8991752	total: 1.77s	remaining: 13.8s
# 114:	learn: 0.8976140	total: 1.78s	remaining: 13.7s
# 115:	learn: 0.8965954	total: 1.78s	remaining: 13.6s
# 116:	learn: 0.8956217	total: 1.79s	remaining: 13.5s
# 117:	learn: 0.8948440	total: 1.83s	remaining: 13.7s
# 118:	learn: 0.8933719	total: 1.84s	remaining: 13.6s
# 119:	learn: 0.8919170	total: 1.85s	remaining: 13.6s
# 120:	learn: 0.8904283	total: 1.86s	remaining: 13.5s
# 121:	learn: 0.8890990	total: 1.87s	remaining: 13.5s
# 122:	learn: 0.8876159	total: 1.87s	remaining: 13.4s
# 123:	learn: 0.8865301	total: 1.88s	remaining: 13.3s
# 124:	learn: 0.8850999	total: 1.89s	remaining: 13.2s
# 125:	learn: 0.8839600	total: 1.89s	remaining: 13.1s
# 126:	learn: 0.8826463	total: 1.89s	remaining: 13s
# 127:	learn: 0.8814218	total: 1.9s	remaining: 12.9s
# 128:	learn: 0.8803432	total: 1.9s	remaining: 12.9s
# 129:	learn: 0.8796591	total: 1.91s	remaining: 12.8s
# 130:	learn: 0.8777936	total: 1.92s	remaining: 12.7s
# 131:	learn: 0.8767193	total: 1.92s	remaining: 12.6s
# 132:	learn: 0.8754701	total: 1.92s	remaining: 12.5s
# 133:	learn: 0.8745146	total: 1.93s	remaining: 12.5s
# 134:	learn: 0.8721113	total: 1.93s	remaining: 12.4s
# 135:	learn: 0.8709485	total: 1.94s	remaining: 12.3s
# 136:	learn: 0.8688775	total: 1.94s	remaining: 12.2s
# 137:	learn: 0.8669834	total: 1.95s	remaining: 12.2s
# 138:	learn: 0.8660523	total: 1.95s	remaining: 12.1s
# 139:	learn: 0.8655399	total: 1.96s	remaining: 12s
# 140:	learn: 0.8645033	total: 1.96s	remaining: 12s
# 141:	learn: 0.8629748	total: 1.97s	remaining: 11.9s
# 142:	learn: 0.8619112	total: 1.97s	remaining: 11.8s
# 143:	learn: 0.8612960	total: 1.98s	remaining: 11.8s
# 144:	learn: 0.8600257	total: 1.98s	remaining: 11.7s
# 145:	learn: 0.8585344	total: 1.99s	remaining: 11.6s
# 146:	learn: 0.8572918	total: 1.99s	remaining: 11.6s
# 147:	learn: 0.8561431	total: 2s	remaining: 11.5s
# 148:	learn: 0.8550492	total: 2s	remaining: 11.4s
# 149:	learn: 0.8542875	total: 2.01s	remaining: 11.4s
# 150:	learn: 0.8532634	total: 2.01s	remaining: 11.3s
# 151:	learn: 0.8524565	total: 2.02s	remaining: 11.2s
# 152:	learn: 0.8516671	total: 2.02s	remaining: 11.2s
# 153:	learn: 0.8503558	total: 2.03s	remaining: 11.1s
# 154:	learn: 0.8492858	total: 2.03s	remaining: 11.1s
# 155:	learn: 0.8479837	total: 2.03s	remaining: 11s
# 156:	learn: 0.8464329	total: 2.04s	remaining: 11s
# 157:	learn: 0.8451869	total: 2.05s	remaining: 10.9s
# 158:	learn: 0.8433493	total: 2.05s	remaining: 10.9s
# 159:	learn: 0.8426518	total: 2.06s	remaining: 10.8s
# 160:	learn: 0.8422267	total: 2.06s	remaining: 10.8s
# 161:	learn: 0.8412599	total: 2.07s	remaining: 10.7s
# 162:	learn: 0.8403254	total: 2.08s	remaining: 10.7s
# 163:	learn: 0.8395051	total: 2.08s	remaining: 10.6s
# 164:	learn: 0.8373005	total: 2.09s	remaining: 10.6s
# 165:	learn: 0.8359189	total: 2.09s	remaining: 10.5s
# 166:	learn: 0.8345198	total: 2.1s	remaining: 10.5s
# 167:	learn: 0.8337074	total: 2.1s	remaining: 10.4s
# 168:	learn: 0.8326848	total: 2.11s	remaining: 10.4s
# 169:	learn: 0.8313520	total: 2.12s	remaining: 10.3s
# 170:	learn: 0.8303042	total: 2.12s	remaining: 10.3s
# 171:	learn: 0.8286046	total: 2.13s	remaining: 10.2s
# 172:	learn: 0.8273270	total: 2.13s	remaining: 10.2s
# 173:	learn: 0.8260823	total: 2.14s	remaining: 10.2s
# 174:	learn: 0.8253369	total: 2.15s	remaining: 10.1s
# 175:	learn: 0.8238680	total: 2.15s	remaining: 10.1s
# 176:	learn: 0.8228482	total: 2.17s	remaining: 10.1s
# 177:	learn: 0.8218124	total: 2.17s	remaining: 10s
# 178:	learn: 0.8202366	total: 2.18s	remaining: 10s
# 179:	learn: 0.8192266	total: 2.19s	remaining: 9.96s
# 180:	learn: 0.8177357	total: 2.19s	remaining: 9.91s
# 181:	learn: 0.8162826	total: 2.2s	remaining: 9.9s
# 182:	learn: 0.8151221	total: 2.21s	remaining: 9.85s
# 183:	learn: 0.8140464	total: 2.22s	remaining: 9.83s
# 184:	learn: 0.8132049	total: 2.22s	remaining: 9.79s
# 185:	learn: 0.8119109	total: 2.23s	remaining: 9.76s
# 186:	learn: 0.8107861	total: 2.23s	remaining: 9.71s
# 187:	learn: 0.8096411	total: 2.24s	remaining: 9.67s
# 188:	learn: 0.8090235	total: 2.25s	remaining: 9.65s
# 189:	learn: 0.8078926	total: 2.25s	remaining: 9.61s
# 190:	learn: 0.8070110	total: 2.26s	remaining: 9.59s
# 191:	learn: 0.8050647	total: 2.27s	remaining: 9.55s
# 192:	learn: 0.8037312	total: 2.28s	remaining: 9.52s
# 193:	learn: 0.8026765	total: 2.28s	remaining: 9.47s
# 194:	learn: 0.8016236	total: 2.29s	remaining: 9.44s
# 195:	learn: 0.8008309	total: 2.29s	remaining: 9.41s
# 196:	learn: 0.7998245	total: 2.3s	remaining: 9.37s
# 197:	learn: 0.7986400	total: 2.3s	remaining: 9.33s
# 198:	learn: 0.7980293	total: 2.31s	remaining: 9.3s
# 199:	learn: 0.7969865	total: 2.31s	remaining: 9.26s
# 200:	learn: 0.7958616	total: 2.32s	remaining: 9.22s
# 201:	learn: 0.7951371	total: 2.33s	remaining: 9.19s
# 202:	learn: 0.7940906	total: 2.33s	remaining: 9.15s
# 203:	learn: 0.7928000	total: 2.33s	remaining: 9.11s
# 204:	learn: 0.7915166	total: 2.34s	remaining: 9.08s
# 205:	learn: 0.7906553	total: 2.35s	remaining: 9.04s
# 206:	learn: 0.7900451	total: 2.35s	remaining: 9s
# 207:	learn: 0.7887474	total: 2.36s	remaining: 8.97s
# 208:	learn: 0.7881422	total: 2.36s	remaining: 8.94s
# 209:	learn: 0.7875802	total: 2.37s	remaining: 8.9s
# 210:	learn: 0.7864122	total: 2.37s	remaining: 8.87s
# 211:	learn: 0.7850231	total: 2.38s	remaining: 8.85s
# 212:	learn: 0.7841375	total: 2.38s	remaining: 8.81s
# 213:	learn: 0.7830848	total: 2.39s	remaining: 8.78s
# 214:	learn: 0.7823067	total: 2.4s	remaining: 8.74s
# 215:	learn: 0.7814445	total: 2.4s	remaining: 8.71s
# 216:	learn: 0.7803546	total: 2.41s	remaining: 8.68s
# 217:	learn: 0.7791136	total: 2.41s	remaining: 8.65s
# 218:	learn: 0.7779917	total: 2.41s	remaining: 8.61s
# 219:	learn: 0.7770046	total: 2.42s	remaining: 8.59s
# 220:	learn: 0.7762766	total: 2.42s	remaining: 8.55s
# 221:	learn: 0.7756832	total: 2.43s	remaining: 8.51s
# 222:	learn: 0.7747734	total: 2.44s	remaining: 8.49s
# 223:	learn: 0.7743640	total: 2.44s	remaining: 8.46s
# 224:	learn: 0.7735473	total: 2.44s	remaining: 8.42s
# 225:	learn: 0.7725222	total: 2.45s	remaining: 8.4s
# 226:	learn: 0.7712773	total: 2.46s	remaining: 8.36s
# 227:	learn: 0.7700732	total: 2.46s	remaining: 8.32s
# 228:	learn: 0.7693519	total: 2.46s	remaining: 8.29s
# 229:	learn: 0.7679491	total: 2.47s	remaining: 8.27s
# 230:	learn: 0.7666909	total: 2.47s	remaining: 8.24s
# 231:	learn: 0.7656700	total: 2.48s	remaining: 8.21s
# 232:	learn: 0.7646016	total: 2.48s	remaining: 8.18s
# 233:	learn: 0.7642919	total: 2.49s	remaining: 8.14s
# 234:	learn: 0.7637191	total: 2.49s	remaining: 8.11s
# 235:	learn: 0.7630635	total: 2.5s	remaining: 8.08s
# 236:	learn: 0.7620838	total: 2.5s	remaining: 8.05s
# 237:	learn: 0.7608494	total: 2.5s	remaining: 8.02s
# 238:	learn: 0.7597849	total: 2.51s	remaining: 7.98s
# 239:	learn: 0.7585448	total: 2.51s	remaining: 7.96s
# 240:	learn: 0.7575184	total: 2.52s	remaining: 7.93s
# 241:	learn: 0.7560819	total: 2.52s	remaining: 7.9s
# 242:	learn: 0.7553440	total: 2.52s	remaining: 7.87s
# 243:	learn: 0.7548634	total: 2.53s	remaining: 7.84s
# 244:	learn: 0.7539888	total: 2.53s	remaining: 7.81s
# 245:	learn: 0.7527965	total: 2.54s	remaining: 7.78s
# 246:	learn: 0.7521985	total: 2.54s	remaining: 7.75s
# 247:	learn: 0.7509456	total: 2.55s	remaining: 7.72s
# 248:	learn: 0.7501623	total: 2.55s	remaining: 7.7s
# 249:	learn: 0.7496540	total: 2.56s	remaining: 7.67s
# 250:	learn: 0.7483990	total: 2.56s	remaining: 7.64s
# 251:	learn: 0.7474070	total: 2.56s	remaining: 7.62s
# 252:	learn: 0.7462273	total: 2.57s	remaining: 7.59s
# 253:	learn: 0.7454935	total: 2.58s	remaining: 7.57s
# 254:	learn: 0.7445259	total: 2.58s	remaining: 7.54s
# 255:	learn: 0.7435982	total: 2.58s	remaining: 7.51s
# 256:	learn: 0.7425100	total: 2.59s	remaining: 7.49s
# 257:	learn: 0.7417283	total: 2.59s	remaining: 7.46s
# 258:	learn: 0.7406983	total: 2.6s	remaining: 7.44s
# 259:	learn: 0.7399955	total: 2.6s	remaining: 7.41s
# 260:	learn: 0.7394015	total: 2.61s	remaining: 7.39s
# 261:	learn: 0.7384749	total: 2.61s	remaining: 7.36s
# 262:	learn: 0.7373935	total: 2.62s	remaining: 7.33s
# 263:	learn: 0.7362157	total: 2.62s	remaining: 7.31s
# 264:	learn: 0.7353048	total: 2.63s	remaining: 7.29s
# 265:	learn: 0.7342775	total: 2.63s	remaining: 7.26s
# 266:	learn: 0.7331913	total: 2.64s	remaining: 7.24s
# 267:	learn: 0.7323149	total: 2.64s	remaining: 7.22s
# 268:	learn: 0.7317282	total: 2.65s	remaining: 7.2s
# 269:	learn: 0.7309433	total: 2.65s	remaining: 7.17s
# 270:	learn: 0.7302180	total: 2.66s	remaining: 7.16s
# 271:	learn: 0.7296954	total: 2.66s	remaining: 7.13s
# 272:	learn: 0.7287881	total: 2.67s	remaining: 7.11s
# 273:	learn: 0.7276039	total: 2.67s	remaining: 7.09s
# 274:	learn: 0.7265053	total: 2.68s	remaining: 7.06s
# 275:	learn: 0.7257052	total: 2.68s	remaining: 7.04s
# 276:	learn: 0.7245284	total: 2.69s	remaining: 7.02s
# 277:	learn: 0.7239828	total: 2.7s	remaining: 7s
# 278:	learn: 0.7234215	total: 2.7s	remaining: 6.98s
# 279:	learn: 0.7228527	total: 2.71s	remaining: 6.96s
# 280:	learn: 0.7215102	total: 2.71s	remaining: 6.93s
# 281:	learn: 0.7204105	total: 2.71s	remaining: 6.91s
# 282:	learn: 0.7188584	total: 2.72s	remaining: 6.89s
# 283:	learn: 0.7176791	total: 2.72s	remaining: 6.86s
# 284:	learn: 0.7167796	total: 2.73s	remaining: 6.85s
# 285:	learn: 0.7157956	total: 2.73s	remaining: 6.83s
# 286:	learn: 0.7149557	total: 2.74s	remaining: 6.8s
# 287:	learn: 0.7141922	total: 2.74s	remaining: 6.78s
# 288:	learn: 0.7135411	total: 2.75s	remaining: 6.76s
# 289:	learn: 0.7128885	total: 2.75s	remaining: 6.74s
# 290:	learn: 0.7120758	total: 2.76s	remaining: 6.72s
# 291:	learn: 0.7114183	total: 2.76s	remaining: 6.7s
# 292:	learn: 0.7107413	total: 2.77s	remaining: 6.68s
# 293:	learn: 0.7099381	total: 2.77s	remaining: 6.66s
# 294:	learn: 0.7094083	total: 2.77s	remaining: 6.63s
# 295:	learn: 0.7088298	total: 2.78s	remaining: 6.62s
# 296:	learn: 0.7076594	total: 2.79s	remaining: 6.59s
# 297:	learn: 0.7066281	total: 2.79s	remaining: 6.57s
# 298:	learn: 0.7058284	total: 2.79s	remaining: 6.55s
# 299:	learn: 0.7049332	total: 2.8s	remaining: 6.53s
# 300:	learn: 0.7043510	total: 2.8s	remaining: 6.51s
# 301:	learn: 0.7033922	total: 2.81s	remaining: 6.49s
# 302:	learn: 0.7028227	total: 2.82s	remaining: 6.48s
# 303:	learn: 0.7020029	total: 2.82s	remaining: 6.46s
# 304:	learn: 0.7011598	total: 2.82s	remaining: 6.43s
# 305:	learn: 0.7005757	total: 2.83s	remaining: 6.42s
# 306:	learn: 0.6999727	total: 2.83s	remaining: 6.4s
# 307:	learn: 0.6995947	total: 2.84s	remaining: 6.38s
# 308:	learn: 0.6984750	total: 2.85s	remaining: 6.36s
# 309:	learn: 0.6978450	total: 2.85s	remaining: 6.34s
# 310:	learn: 0.6972445	total: 2.85s	remaining: 6.32s
# 311:	learn: 0.6964300	total: 2.86s	remaining: 6.3s
# 312:	learn: 0.6956275	total: 2.86s	remaining: 6.28s
# 313:	learn: 0.6949943	total: 2.87s	remaining: 6.26s
# 314:	learn: 0.6943166	total: 2.87s	remaining: 6.24s
# 315:	learn: 0.6933952	total: 2.87s	remaining: 6.22s
# 316:	learn: 0.6923062	total: 2.88s	remaining: 6.2s
# 317:	learn: 0.6911395	total: 2.88s	remaining: 6.18s
# 318:	learn: 0.6904570	total: 2.89s	remaining: 6.16s
# 319:	learn: 0.6900010	total: 2.89s	remaining: 6.15s
# 320:	learn: 0.6891917	total: 2.9s	remaining: 6.13s
# 321:	learn: 0.6884995	total: 2.9s	remaining: 6.11s
# 322:	learn: 0.6876633	total: 2.91s	remaining: 6.1s
# 323:	learn: 0.6867872	total: 2.91s	remaining: 6.08s
# 324:	learn: 0.6859035	total: 2.92s	remaining: 6.06s
# 325:	learn: 0.6853658	total: 2.92s	remaining: 6.04s
# 326:	learn: 0.6843836	total: 2.93s	remaining: 6.02s
# 327:	learn: 0.6834598	total: 2.93s	remaining: 6s
# 328:	learn: 0.6827020	total: 2.93s	remaining: 5.99s
# 329:	learn: 0.6818004	total: 2.94s	remaining: 5.97s
# 330:	learn: 0.6809759	total: 2.94s	remaining: 5.95s
# 331:	learn: 0.6800019	total: 2.95s	remaining: 5.93s
# 332:	learn: 0.6794147	total: 2.95s	remaining: 5.92s
# 333:	learn: 0.6790445	total: 2.96s	remaining: 5.9s
# 334:	learn: 0.6783188	total: 2.96s	remaining: 5.88s
# 335:	learn: 0.6778155	total: 2.97s	remaining: 5.87s
# 336:	learn: 0.6768637	total: 2.97s	remaining: 5.85s
# 337:	learn: 0.6758066	total: 2.98s	remaining: 5.83s
# 338:	learn: 0.6753131	total: 2.98s	remaining: 5.82s
# 339:	learn: 0.6745391	total: 2.99s	remaining: 5.8s
# 340:	learn: 0.6738780	total: 2.99s	remaining: 5.78s
# 341:	learn: 0.6733089	total: 3s	remaining: 5.76s
# 342:	learn: 0.6726973	total: 3s	remaining: 5.75s
# 343:	learn: 0.6721462	total: 3s	remaining: 5.73s
# 344:	learn: 0.6714134	total: 3.01s	remaining: 5.71s
# 345:	learn: 0.6701531	total: 3.01s	remaining: 5.69s
# 346:	learn: 0.6694093	total: 3.02s	remaining: 5.68s
# 347:	learn: 0.6686676	total: 3.02s	remaining: 5.66s
# 348:	learn: 0.6678154	total: 3.02s	remaining: 5.64s
# 349:	learn: 0.6670444	total: 3.03s	remaining: 5.63s
# 350:	learn: 0.6662239	total: 3.03s	remaining: 5.61s
# 351:	learn: 0.6656264	total: 3.04s	remaining: 5.59s
# 352:	learn: 0.6647575	total: 3.04s	remaining: 5.58s
# 353:	learn: 0.6641853	total: 3.05s	remaining: 5.56s
# 354:	learn: 0.6630023	total: 3.05s	remaining: 5.55s
# 355:	learn: 0.6621746	total: 3.06s	remaining: 5.53s
# 356:	learn: 0.6610978	total: 3.06s	remaining: 5.52s
# 357:	learn: 0.6601656	total: 3.07s	remaining: 5.5s
# 358:	learn: 0.6595613	total: 3.07s	remaining: 5.49s
# 359:	learn: 0.6587115	total: 3.08s	remaining: 5.47s
# 360:	learn: 0.6584374	total: 3.08s	remaining: 5.46s
# 361:	learn: 0.6577192	total: 3.08s	remaining: 5.44s
# 362:	learn: 0.6567536	total: 3.09s	remaining: 5.42s
# 363:	learn: 0.6561327	total: 3.1s	remaining: 5.42s
# 364:	learn: 0.6554759	total: 3.11s	remaining: 5.4s
# 365:	learn: 0.6549267	total: 3.11s	remaining: 5.39s
# 366:	learn: 0.6539609	total: 3.12s	remaining: 5.38s
# 367:	learn: 0.6533192	total: 3.12s	remaining: 5.36s
# 368:	learn: 0.6524651	total: 3.12s	remaining: 5.34s
# 369:	learn: 0.6513518	total: 3.13s	remaining: 5.33s
# 370:	learn: 0.6507178	total: 3.13s	remaining: 5.31s
# 371:	learn: 0.6499717	total: 3.14s	remaining: 5.3s
# 372:	learn: 0.6494323	total: 3.14s	remaining: 5.29s
# 373:	learn: 0.6487060	total: 3.15s	remaining: 5.27s
# 374:	learn: 0.6481694	total: 3.15s	remaining: 5.25s
# 375:	learn: 0.6479500	total: 3.16s	remaining: 5.24s
# 376:	learn: 0.6473093	total: 3.16s	remaining: 5.23s
# 377:	learn: 0.6466218	total: 3.17s	remaining: 5.21s
# 378:	learn: 0.6459872	total: 3.17s	remaining: 5.19s
# 379:	learn: 0.6454961	total: 3.17s	remaining: 5.18s
# 380:	learn: 0.6446708	total: 3.18s	remaining: 5.17s
# 381:	learn: 0.6438823	total: 3.18s	remaining: 5.15s
# 382:	learn: 0.6428910	total: 3.19s	remaining: 5.14s
# 383:	learn: 0.6421149	total: 3.2s	remaining: 5.13s
# 384:	learn: 0.6413942	total: 3.2s	remaining: 5.11s
# 385:	learn: 0.6409862	total: 3.21s	remaining: 5.1s
# 386:	learn: 0.6402578	total: 3.21s	remaining: 5.08s
# 387:	learn: 0.6394702	total: 3.21s	remaining: 5.07s
# 388:	learn: 0.6387860	total: 3.22s	remaining: 5.05s
# 389:	learn: 0.6379728	total: 3.22s	remaining: 5.04s
# 390:	learn: 0.6372401	total: 3.23s	remaining: 5.03s
# 391:	learn: 0.6366992	total: 3.23s	remaining: 5.02s
# 392:	learn: 0.6362326	total: 3.24s	remaining: 5s
# 393:	learn: 0.6358434	total: 3.24s	remaining: 4.99s
# 394:	learn: 0.6353782	total: 3.25s	remaining: 4.97s
# 395:	learn: 0.6347704	total: 3.25s	remaining: 4.96s
# 396:	learn: 0.6342269	total: 3.25s	remaining: 4.95s
# 397:	learn: 0.6335110	total: 3.26s	remaining: 4.93s
# 398:	learn: 0.6328855	total: 3.27s	remaining: 4.92s
# 399:	learn: 0.6322947	total: 3.27s	remaining: 4.91s
# 400:	learn: 0.6316815	total: 3.28s	remaining: 4.9s
# 401:	learn: 0.6309730	total: 3.28s	remaining: 4.88s
# 402:	learn: 0.6302720	total: 3.29s	remaining: 4.87s
# 403:	learn: 0.6294441	total: 3.29s	remaining: 4.86s
# 404:	learn: 0.6289725	total: 3.29s	remaining: 4.84s
# 405:	learn: 0.6284669	total: 3.3s	remaining: 4.83s
# 406:	learn: 0.6277081	total: 3.31s	remaining: 4.82s
# 407:	learn: 0.6271540	total: 3.32s	remaining: 4.81s
# 408:	learn: 0.6259426	total: 3.32s	remaining: 4.8s
# 409:	learn: 0.6248725	total: 3.32s	remaining: 4.78s
# 410:	learn: 0.6241469	total: 3.33s	remaining: 4.77s
# 411:	learn: 0.6235052	total: 3.33s	remaining: 4.76s
# 412:	learn: 0.6229658	total: 3.34s	remaining: 4.74s
# 413:	learn: 0.6222874	total: 3.34s	remaining: 4.73s
# 414:	learn: 0.6216549	total: 3.35s	remaining: 4.72s
# 415:	learn: 0.6208756	total: 3.35s	remaining: 4.71s
# 416:	learn: 0.6199299	total: 3.36s	remaining: 4.7s
# 417:	learn: 0.6191454	total: 3.37s	remaining: 4.68s
# 418:	learn: 0.6186791	total: 3.37s	remaining: 4.67s
# 419:	learn: 0.6178508	total: 3.37s	remaining: 4.66s
# 420:	learn: 0.6170207	total: 3.38s	remaining: 4.64s
# 421:	learn: 0.6162002	total: 3.38s	remaining: 4.63s
# 422:	learn: 0.6150436	total: 3.38s	remaining: 4.62s
# 423:	learn: 0.6143554	total: 3.39s	remaining: 4.61s
# 424:	learn: 0.6138807	total: 3.4s	remaining: 4.59s
# 425:	learn: 0.6133331	total: 3.4s	remaining: 4.58s
# 426:	learn: 0.6123114	total: 3.4s	remaining: 4.57s
# 427:	learn: 0.6117955	total: 3.41s	remaining: 4.55s
# 428:	learn: 0.6113226	total: 3.41s	remaining: 4.54s
# 429:	learn: 0.6105263	total: 3.42s	remaining: 4.53s
# 430:	learn: 0.6100391	total: 3.42s	remaining: 4.51s
# 431:	learn: 0.6095548	total: 3.42s	remaining: 4.5s
# 432:	learn: 0.6091244	total: 3.43s	remaining: 4.49s
# 433:	learn: 0.6083791	total: 3.44s	remaining: 4.48s
# 434:	learn: 0.6077548	total: 3.44s	remaining: 4.47s
# 435:	learn: 0.6071450	total: 3.45s	remaining: 4.46s
# 436:	learn: 0.6066416	total: 3.45s	remaining: 4.44s
# 437:	learn: 0.6060314	total: 3.45s	remaining: 4.43s
# 438:	learn: 0.6054465	total: 3.46s	remaining: 4.42s
# 439:	learn: 0.6044976	total: 3.46s	remaining: 4.41s
# 440:	learn: 0.6039533	total: 3.47s	remaining: 4.4s
# 441:	learn: 0.6035474	total: 3.48s	remaining: 4.39s
# 442:	learn: 0.6027635	total: 3.48s	remaining: 4.38s
# 443:	learn: 0.6019358	total: 3.48s	remaining: 4.36s
# 444:	learn: 0.6011366	total: 3.49s	remaining: 4.35s
# 445:	learn: 0.6002539	total: 3.49s	remaining: 4.34s
# 446:	learn: 0.5997278	total: 3.5s	remaining: 4.33s
# 447:	learn: 0.5985459	total: 3.5s	remaining: 4.32s
# 448:	learn: 0.5981007	total: 3.51s	remaining: 4.3s
# 449:	learn: 0.5973434	total: 3.51s	remaining: 4.29s
# 450:	learn: 0.5967421	total: 3.52s	remaining: 4.28s
# 451:	learn: 0.5960087	total: 3.52s	remaining: 4.27s
# 452:	learn: 0.5955315	total: 3.52s	remaining: 4.26s
# 453:	learn: 0.5949181	total: 3.53s	remaining: 4.24s
# 454:	learn: 0.5942116	total: 3.53s	remaining: 4.23s
# 455:	learn: 0.5936899	total: 3.54s	remaining: 4.22s
# 456:	learn: 0.5926712	total: 3.54s	remaining: 4.21s
# 457:	learn: 0.5922197	total: 3.55s	remaining: 4.2s
# 458:	learn: 0.5915968	total: 3.55s	remaining: 4.19s
# 459:	learn: 0.5909178	total: 3.56s	remaining: 4.18s
# 460:	learn: 0.5898917	total: 3.56s	remaining: 4.17s
# 461:	learn: 0.5890354	total: 3.57s	remaining: 4.16s
# 462:	learn: 0.5884738	total: 3.57s	remaining: 4.14s
# 463:	learn: 0.5879607	total: 3.58s	remaining: 4.13s
# 464:	learn: 0.5876389	total: 3.58s	remaining: 4.12s
# 465:	learn: 0.5871862	total: 3.59s	remaining: 4.11s
# 466:	learn: 0.5863688	total: 3.59s	remaining: 4.1s
# 467:	learn: 0.5858408	total: 3.6s	remaining: 4.09s
# 468:	learn: 0.5850968	total: 3.6s	remaining: 4.08s
# 469:	learn: 0.5846065	total: 3.61s	remaining: 4.07s
# 470:	learn: 0.5839943	total: 3.61s	remaining: 4.06s
# 471:	learn: 0.5836330	total: 3.62s	remaining: 4.04s
# 472:	learn: 0.5828072	total: 3.62s	remaining: 4.03s
# 473:	learn: 0.5820377	total: 3.63s	remaining: 4.03s
# 474:	learn: 0.5814968	total: 3.63s	remaining: 4.01s
# 475:	learn: 0.5808742	total: 3.63s	remaining: 4s
# 476:	learn: 0.5799983	total: 3.65s	remaining: 4s
# 477:	learn: 0.5790570	total: 3.65s	remaining: 3.98s
# 478:	learn: 0.5785267	total: 3.65s	remaining: 3.97s
# 479:	learn: 0.5776485	total: 3.66s	remaining: 3.96s
# 480:	learn: 0.5773606	total: 3.66s	remaining: 3.95s
# 481:	learn: 0.5766161	total: 3.67s	remaining: 3.94s
# 482:	learn: 0.5758474	total: 3.67s	remaining: 3.93s
# 483:	learn: 0.5749436	total: 3.68s	remaining: 3.92s
# 484:	learn: 0.5744533	total: 3.69s	remaining: 3.91s
# 485:	learn: 0.5740039	total: 3.69s	remaining: 3.91s
# 486:	learn: 0.5733089	total: 3.7s	remaining: 3.9s
# 487:	learn: 0.5728209	total: 3.7s	remaining: 3.88s
# 488:	learn: 0.5726437	total: 3.71s	remaining: 3.88s
# 489:	learn: 0.5722059	total: 3.71s	remaining: 3.87s
# 490:	learn: 0.5716749	total: 3.73s	remaining: 3.86s
# 491:	learn: 0.5708519	total: 3.73s	remaining: 3.85s
# 492:	learn: 0.5703020	total: 3.73s	remaining: 3.84s
# 493:	learn: 0.5694756	total: 3.74s	remaining: 3.83s
# 494:	learn: 0.5688748	total: 3.75s	remaining: 3.83s
# 495:	learn: 0.5681980	total: 3.76s	remaining: 3.82s
# 496:	learn: 0.5672335	total: 3.76s	remaining: 3.81s
# 497:	learn: 0.5669144	total: 3.77s	remaining: 3.8s
# 498:	learn: 0.5660856	total: 3.78s	remaining: 3.79s
# 499:	learn: 0.5649158	total: 3.79s	remaining: 3.79s
# 500:	learn: 0.5641796	total: 3.8s	remaining: 3.79s
# 501:	learn: 0.5635662	total: 3.81s	remaining: 3.78s
# 502:	learn: 0.5629843	total: 3.81s	remaining: 3.77s
# 503:	learn: 0.5624388	total: 3.82s	remaining: 3.76s
# 504:	learn: 0.5618758	total: 3.83s	remaining: 3.76s
# 505:	learn: 0.5611744	total: 3.84s	remaining: 3.75s
# 506:	learn: 0.5605415	total: 3.85s	remaining: 3.74s
# 507:	learn: 0.5600974	total: 3.85s	remaining: 3.73s
# 508:	learn: 0.5593290	total: 3.86s	remaining: 3.72s
# 509:	learn: 0.5589699	total: 3.87s	remaining: 3.71s
# 510:	learn: 0.5585768	total: 3.87s	remaining: 3.71s
# 511:	learn: 0.5579435	total: 3.88s	remaining: 3.7s
# 512:	learn: 0.5573998	total: 3.89s	remaining: 3.69s
# 513:	learn: 0.5568362	total: 3.89s	remaining: 3.68s
# 514:	learn: 0.5562480	total: 3.9s	remaining: 3.67s
# 515:	learn: 0.5557488	total: 3.9s	remaining: 3.66s
# 516:	learn: 0.5554961	total: 3.92s	remaining: 3.66s
# 517:	learn: 0.5550913	total: 3.92s	remaining: 3.65s
# 518:	learn: 0.5548123	total: 3.93s	remaining: 3.64s
# 519:	learn: 0.5544281	total: 3.93s	remaining: 3.63s
# 520:	learn: 0.5537803	total: 3.94s	remaining: 3.63s
# 521:	learn: 0.5530380	total: 3.95s	remaining: 3.62s
# 522:	learn: 0.5524752	total: 3.95s	remaining: 3.6s
# 523:	learn: 0.5518041	total: 3.96s	remaining: 3.6s
# 524:	learn: 0.5510225	total: 3.97s	remaining: 3.59s
# 525:	learn: 0.5505806	total: 3.98s	remaining: 3.58s
# 526:	learn: 0.5501761	total: 3.99s	remaining: 3.58s
# 527:	learn: 0.5497017	total: 4s	remaining: 3.57s
# 528:	learn: 0.5490022	total: 4.01s	remaining: 3.57s
# 529:	learn: 0.5487999	total: 4.01s	remaining: 3.56s
# 530:	learn: 0.5477689	total: 4.03s	remaining: 3.56s
# 531:	learn: 0.5469393	total: 4.03s	remaining: 3.55s
# 532:	learn: 0.5465301	total: 4.04s	remaining: 3.54s
# 533:	learn: 0.5458501	total: 4.05s	remaining: 3.53s
# 534:	learn: 0.5454727	total: 4.06s	remaining: 3.53s
# 535:	learn: 0.5448986	total: 4.06s	remaining: 3.52s
# 536:	learn: 0.5445901	total: 4.07s	remaining: 3.51s
# 537:	learn: 0.5439926	total: 4.08s	remaining: 3.5s
# 538:	learn: 0.5433299	total: 4.09s	remaining: 3.5s
# 539:	learn: 0.5429836	total: 4.09s	remaining: 3.49s
# 540:	learn: 0.5422750	total: 4.1s	remaining: 3.48s
# 541:	learn: 0.5417996	total: 4.11s	remaining: 3.47s
# 542:	learn: 0.5410078	total: 4.11s	remaining: 3.46s
# 543:	learn: 0.5405100	total: 4.12s	remaining: 3.46s
# 544:	learn: 0.5400445	total: 4.13s	remaining: 3.44s
# 545:	learn: 0.5394768	total: 4.13s	remaining: 3.44s
# 546:	learn: 0.5390596	total: 4.14s	remaining: 3.43s
# 547:	learn: 0.5386220	total: 4.14s	remaining: 3.42s
# 548:	learn: 0.5382060	total: 4.15s	remaining: 3.41s
# 549:	learn: 0.5376011	total: 4.16s	remaining: 3.4s
# 550:	learn: 0.5368222	total: 4.16s	remaining: 3.39s
# 551:	learn: 0.5359556	total: 4.17s	remaining: 3.38s
# 552:	learn: 0.5349226	total: 4.17s	remaining: 3.37s
# 553:	learn: 0.5343088	total: 4.17s	remaining: 3.36s
# 554:	learn: 0.5337763	total: 4.18s	remaining: 3.35s
# 555:	learn: 0.5332994	total: 4.19s	remaining: 3.34s
# 556:	learn: 0.5328502	total: 4.19s	remaining: 3.33s
# 557:	learn: 0.5322477	total: 4.2s	remaining: 3.33s
# 558:	learn: 0.5318255	total: 4.21s	remaining: 3.32s
# 559:	learn: 0.5313980	total: 4.21s	remaining: 3.31s
# 560:	learn: 0.5306145	total: 4.22s	remaining: 3.3s
# 561:	learn: 0.5299318	total: 4.22s	remaining: 3.29s
# 562:	learn: 0.5290520	total: 4.23s	remaining: 3.28s
# 563:	learn: 0.5285551	total: 4.23s	remaining: 3.27s
# 564:	learn: 0.5280726	total: 4.24s	remaining: 3.26s
# 565:	learn: 0.5275478	total: 4.25s	remaining: 3.26s
# 566:	learn: 0.5271861	total: 4.25s	remaining: 3.25s
# 567:	learn: 0.5265472	total: 4.26s	remaining: 3.24s
# 568:	learn: 0.5259938	total: 4.27s	remaining: 3.23s
# 569:	learn: 0.5256435	total: 4.27s	remaining: 3.22s
# 570:	learn: 0.5249688	total: 4.28s	remaining: 3.21s
# 571:	learn: 0.5245149	total: 4.28s	remaining: 3.2s
# 572:	learn: 0.5241579	total: 4.29s	remaining: 3.19s
# 573:	learn: 0.5235152	total: 4.29s	remaining: 3.19s
# 574:	learn: 0.5228829	total: 4.3s	remaining: 3.18s
# 575:	learn: 0.5221693	total: 4.3s	remaining: 3.17s
# 576:	learn: 0.5216084	total: 4.31s	remaining: 3.16s
# 577:	learn: 0.5210651	total: 4.32s	remaining: 3.15s
# 578:	learn: 0.5205222	total: 4.32s	remaining: 3.14s
# 579:	learn: 0.5200356	total: 4.33s	remaining: 3.13s
# 580:	learn: 0.5196506	total: 4.33s	remaining: 3.13s
# 581:	learn: 0.5190115	total: 4.35s	remaining: 3.12s
# 582:	learn: 0.5183844	total: 4.35s	remaining: 3.11s
# 583:	learn: 0.5176238	total: 4.36s	remaining: 3.11s
# 584:	learn: 0.5172189	total: 4.37s	remaining: 3.1s
# 585:	learn: 0.5168234	total: 4.38s	remaining: 3.09s
# 586:	learn: 0.5161913	total: 4.38s	remaining: 3.08s
# 587:	learn: 0.5152728	total: 4.39s	remaining: 3.08s
# 588:	learn: 0.5146159	total: 4.4s	remaining: 3.07s
# 589:	learn: 0.5140876	total: 4.41s	remaining: 3.06s
# 590:	learn: 0.5134541	total: 4.42s	remaining: 3.06s
# 591:	learn: 0.5128627	total: 4.42s	remaining: 3.05s
# 592:	learn: 0.5123200	total: 4.43s	remaining: 3.04s
# 593:	learn: 0.5119584	total: 4.44s	remaining: 3.03s
# 594:	learn: 0.5116374	total: 4.44s	remaining: 3.02s
# 595:	learn: 0.5112067	total: 4.45s	remaining: 3.02s
# 596:	learn: 0.5106047	total: 4.46s	remaining: 3.01s
# 597:	learn: 0.5099037	total: 4.47s	remaining: 3s
# 598:	learn: 0.5091882	total: 4.47s	remaining: 3s
# 599:	learn: 0.5084931	total: 4.49s	remaining: 2.99s
# 600:	learn: 0.5080623	total: 4.49s	remaining: 2.98s
# 601:	learn: 0.5076684	total: 4.5s	remaining: 2.98s
# 602:	learn: 0.5073472	total: 4.51s	remaining: 2.97s
# 603:	learn: 0.5065622	total: 4.52s	remaining: 2.96s
# 604:	learn: 0.5061002	total: 4.52s	remaining: 2.95s
# 605:	learn: 0.5058558	total: 4.53s	remaining: 2.95s
# 606:	learn: 0.5051824	total: 4.54s	remaining: 2.94s
# 607:	learn: 0.5044040	total: 4.55s	remaining: 2.94s
# 608:	learn: 0.5039696	total: 4.57s	remaining: 2.93s
# 609:	learn: 0.5034751	total: 4.57s	remaining: 2.92s
# 610:	learn: 0.5028782	total: 4.59s	remaining: 2.92s
# 611:	learn: 0.5023530	total: 4.6s	remaining: 2.91s
# 612:	learn: 0.5019422	total: 4.6s	remaining: 2.91s
# 613:	learn: 0.5015297	total: 4.62s	remaining: 2.9s
# 614:	learn: 0.5009247	total: 4.62s	remaining: 2.89s
# 615:	learn: 0.5004936	total: 4.63s	remaining: 2.88s
# 616:	learn: 0.4999884	total: 4.63s	remaining: 2.88s
# 617:	learn: 0.4990065	total: 4.64s	remaining: 2.87s
# 618:	learn: 0.4985959	total: 4.65s	remaining: 2.86s
# 619:	learn: 0.4977985	total: 4.66s	remaining: 2.86s
# 620:	learn: 0.4972641	total: 4.67s	remaining: 2.85s
# 621:	learn: 0.4969011	total: 4.68s	remaining: 2.84s
# 622:	learn: 0.4962618	total: 4.68s	remaining: 2.83s
# 623:	learn: 0.4958494	total: 4.69s	remaining: 2.83s
# 624:	learn: 0.4955382	total: 4.7s	remaining: 2.82s
# 625:	learn: 0.4950307	total: 4.71s	remaining: 2.81s
# 626:	learn: 0.4942113	total: 4.71s	remaining: 2.8s
# 627:	learn: 0.4938464	total: 4.72s	remaining: 2.8s
# 628:	learn: 0.4932738	total: 4.73s	remaining: 2.79s
# 629:	learn: 0.4926687	total: 4.74s	remaining: 2.78s
# 630:	learn: 0.4921445	total: 4.74s	remaining: 2.77s
# 631:	learn: 0.4917720	total: 4.75s	remaining: 2.76s
# 632:	learn: 0.4912252	total: 4.75s	remaining: 2.75s
# 633:	learn: 0.4908902	total: 4.76s	remaining: 2.75s
# 634:	learn: 0.4903802	total: 4.76s	remaining: 2.74s
# 635:	learn: 0.4899143	total: 4.77s	remaining: 2.73s
# 636:	learn: 0.4892071	total: 4.77s	remaining: 2.72s
# 637:	learn: 0.4887067	total: 4.78s	remaining: 2.71s
# 638:	learn: 0.4882277	total: 4.78s	remaining: 2.7s
# 639:	learn: 0.4875013	total: 4.79s	remaining: 2.69s
# 640:	learn: 0.4870111	total: 4.79s	remaining: 2.69s
# 641:	learn: 0.4864252	total: 4.8s	remaining: 2.68s
# 642:	learn: 0.4859761	total: 4.8s	remaining: 2.67s
# 643:	learn: 0.4855120	total: 4.81s	remaining: 2.66s
# 644:	learn: 0.4849543	total: 4.81s	remaining: 2.65s
# 645:	learn: 0.4841624	total: 4.82s	remaining: 2.64s
# 646:	learn: 0.4837660	total: 4.82s	remaining: 2.63s
# 647:	learn: 0.4832428	total: 4.83s	remaining: 2.62s
# 648:	learn: 0.4828479	total: 4.83s	remaining: 2.61s
# 649:	learn: 0.4821250	total: 4.84s	remaining: 2.6s
# 650:	learn: 0.4815363	total: 4.84s	remaining: 2.6s
# 651:	learn: 0.4808041	total: 4.85s	remaining: 2.59s
# 652:	learn: 0.4803884	total: 4.85s	remaining: 2.58s
# 653:	learn: 0.4800347	total: 4.86s	remaining: 2.57s
# 654:	learn: 0.4792557	total: 4.87s	remaining: 2.56s
# 655:	learn: 0.4788578	total: 4.87s	remaining: 2.55s
# 656:	learn: 0.4784104	total: 4.88s	remaining: 2.55s
# 657:	learn: 0.4779298	total: 4.89s	remaining: 2.54s
# 658:	learn: 0.4777143	total: 4.89s	remaining: 2.53s
# 659:	learn: 0.4772922	total: 4.9s	remaining: 2.52s
# 660:	learn: 0.4766589	total: 4.9s	remaining: 2.52s
# 661:	learn: 0.4761909	total: 4.91s	remaining: 2.51s
# 662:	learn: 0.4758773	total: 4.92s	remaining: 2.5s
# 663:	learn: 0.4754187	total: 4.93s	remaining: 2.5s
# 664:	learn: 0.4751210	total: 4.94s	remaining: 2.49s
# 665:	learn: 0.4747028	total: 4.95s	remaining: 2.48s
# 666:	learn: 0.4743854	total: 4.95s	remaining: 2.47s
# 667:	learn: 0.4739824	total: 4.96s	remaining: 2.46s
# 668:	learn: 0.4734828	total: 4.97s	remaining: 2.46s
# 669:	learn: 0.4730534	total: 4.98s	remaining: 2.45s
# 670:	learn: 0.4725144	total: 4.98s	remaining: 2.44s
# 671:	learn: 0.4720891	total: 4.99s	remaining: 2.43s
# 672:	learn: 0.4716032	total: 4.99s	remaining: 2.43s
# 673:	learn: 0.4712570	total: 5s	remaining: 2.42s
# 674:	learn: 0.4706072	total: 5.01s	remaining: 2.41s
# 675:	learn: 0.4700778	total: 5.01s	remaining: 2.4s
# 676:	learn: 0.4695341	total: 5.02s	remaining: 2.39s
# 677:	learn: 0.4690758	total: 5.02s	remaining: 2.39s
# 678:	learn: 0.4684878	total: 5.03s	remaining: 2.38s
# 679:	learn: 0.4681566	total: 5.03s	remaining: 2.37s
# 680:	learn: 0.4676071	total: 5.04s	remaining: 2.36s
# 681:	learn: 0.4670969	total: 5.04s	remaining: 2.35s
# 682:	learn: 0.4665297	total: 5.05s	remaining: 2.34s
# 683:	learn: 0.4660551	total: 5.05s	remaining: 2.33s
# 684:	learn: 0.4654154	total: 5.06s	remaining: 2.33s
# 685:	learn: 0.4651604	total: 5.07s	remaining: 2.32s
# 686:	learn: 0.4647728	total: 5.07s	remaining: 2.31s
# 687:	learn: 0.4642637	total: 5.07s	remaining: 2.3s
# 688:	learn: 0.4640158	total: 5.08s	remaining: 2.29s
# 689:	learn: 0.4636081	total: 5.08s	remaining: 2.28s
# 690:	learn: 0.4628831	total: 5.09s	remaining: 2.27s
# 691:	learn: 0.4625303	total: 5.09s	remaining: 2.27s
# 692:	learn: 0.4621513	total: 5.11s	remaining: 2.26s
# 693:	learn: 0.4617261	total: 5.11s	remaining: 2.25s
# 694:	learn: 0.4612437	total: 5.11s	remaining: 2.24s
# 695:	learn: 0.4607161	total: 5.12s	remaining: 2.24s
# 696:	learn: 0.4600271	total: 5.12s	remaining: 2.23s
# 697:	learn: 0.4594706	total: 5.13s	remaining: 2.22s
# 698:	learn: 0.4591527	total: 5.13s	remaining: 2.21s
# 699:	learn: 0.4587786	total: 5.14s	remaining: 2.2s
# 700:	learn: 0.4582861	total: 5.14s	remaining: 2.19s
# 701:	learn: 0.4579548	total: 5.15s	remaining: 2.19s
# 702:	learn: 0.4575333	total: 5.16s	remaining: 2.18s
# 703:	learn: 0.4569810	total: 5.17s	remaining: 2.17s
# 704:	learn: 0.4566560	total: 5.17s	remaining: 2.16s
# 705:	learn: 0.4560718	total: 5.17s	remaining: 2.15s
# 706:	learn: 0.4555934	total: 5.18s	remaining: 2.15s
# 707:	learn: 0.4551228	total: 5.19s	remaining: 2.14s
# 708:	learn: 0.4547383	total: 5.19s	remaining: 2.13s
# 709:	learn: 0.4544365	total: 5.2s	remaining: 2.12s
# 710:	learn: 0.4539790	total: 5.2s	remaining: 2.11s
# 711:	learn: 0.4536055	total: 5.21s	remaining: 2.1s
# 712:	learn: 0.4532953	total: 5.21s	remaining: 2.1s
# 713:	learn: 0.4527434	total: 5.22s	remaining: 2.09s
# 714:	learn: 0.4521626	total: 5.22s	remaining: 2.08s
# 715:	learn: 0.4517414	total: 5.23s	remaining: 2.07s
# 716:	learn: 0.4510226	total: 5.23s	remaining: 2.06s
# 717:	learn: 0.4502985	total: 5.24s	remaining: 2.06s
# 718:	learn: 0.4499166	total: 5.25s	remaining: 2.05s
# 719:	learn: 0.4492576	total: 5.25s	remaining: 2.04s
# 720:	learn: 0.4488384	total: 5.26s	remaining: 2.04s
# 721:	learn: 0.4483813	total: 5.26s	remaining: 2.03s
# 722:	learn: 0.4478861	total: 5.27s	remaining: 2.02s
# 723:	learn: 0.4475553	total: 5.28s	remaining: 2.01s
# 724:	learn: 0.4473722	total: 5.28s	remaining: 2s
# 725:	learn: 0.4470550	total: 5.29s	remaining: 2s
# 726:	learn: 0.4467988	total: 5.3s	remaining: 1.99s
# 727:	learn: 0.4465270	total: 5.3s	remaining: 1.98s
# 728:	learn: 0.4460218	total: 5.31s	remaining: 1.97s
# 729:	learn: 0.4456929	total: 5.31s	remaining: 1.97s
# 730:	learn: 0.4453447	total: 5.32s	remaining: 1.96s
# 731:	learn: 0.4447934	total: 5.33s	remaining: 1.95s
# 732:	learn: 0.4444792	total: 5.33s	remaining: 1.94s
# 733:	learn: 0.4440416	total: 5.34s	remaining: 1.93s
# 734:	learn: 0.4437834	total: 5.34s	remaining: 1.93s
# 735:	learn: 0.4431148	total: 5.35s	remaining: 1.92s
# 736:	learn: 0.4427431	total: 5.35s	remaining: 1.91s
# 737:	learn: 0.4423338	total: 5.35s	remaining: 1.9s
# 738:	learn: 0.4419238	total: 5.36s	remaining: 1.89s
# 739:	learn: 0.4414512	total: 5.36s	remaining: 1.88s
# 740:	learn: 0.4411941	total: 5.37s	remaining: 1.88s
# 741:	learn: 0.4408774	total: 5.37s	remaining: 1.87s
# 742:	learn: 0.4404998	total: 5.37s	remaining: 1.86s
# 743:	learn: 0.4398016	total: 5.38s	remaining: 1.85s
# 744:	learn: 0.4393030	total: 5.38s	remaining: 1.84s
# 745:	learn: 0.4390311	total: 5.39s	remaining: 1.83s
# 746:	learn: 0.4385451	total: 5.39s	remaining: 1.83s
# 747:	learn: 0.4380006	total: 5.4s	remaining: 1.82s
# 748:	learn: 0.4375584	total: 5.4s	remaining: 1.81s
# 749:	learn: 0.4372267	total: 5.41s	remaining: 1.8s
# 750:	learn: 0.4369183	total: 5.41s	remaining: 1.79s
# 751:	learn: 0.4363688	total: 5.42s	remaining: 1.79s
# 752:	learn: 0.4361081	total: 5.42s	remaining: 1.78s
# 753:	learn: 0.4354865	total: 5.42s	remaining: 1.77s
# 754:	learn: 0.4348631	total: 5.43s	remaining: 1.76s
# 755:	learn: 0.4345922	total: 5.43s	remaining: 1.75s
# 756:	learn: 0.4343582	total: 5.44s	remaining: 1.75s
# 757:	learn: 0.4339620	total: 5.44s	remaining: 1.74s
# 758:	learn: 0.4337049	total: 5.45s	remaining: 1.73s
# 759:	learn: 0.4334159	total: 5.45s	remaining: 1.72s
# 760:	learn: 0.4328340	total: 5.46s	remaining: 1.71s
# 761:	learn: 0.4324911	total: 5.46s	remaining: 1.71s
# 762:	learn: 0.4322477	total: 5.47s	remaining: 1.7s
# 763:	learn: 0.4317658	total: 5.48s	remaining: 1.69s
# 764:	learn: 0.4315661	total: 5.48s	remaining: 1.68s
# 765:	learn: 0.4310924	total: 5.49s	remaining: 1.68s
# 766:	learn: 0.4307824	total: 5.5s	remaining: 1.67s
# 767:	learn: 0.4304726	total: 5.5s	remaining: 1.66s
# 768:	learn: 0.4299181	total: 5.51s	remaining: 1.65s
# 769:	learn: 0.4294649	total: 5.51s	remaining: 1.65s
# 770:	learn: 0.4289469	total: 5.52s	remaining: 1.64s
# 771:	learn: 0.4285017	total: 5.53s	remaining: 1.63s
# 772:	learn: 0.4282237	total: 5.53s	remaining: 1.62s
# 773:	learn: 0.4277594	total: 5.54s	remaining: 1.62s
# 774:	learn: 0.4275025	total: 5.55s	remaining: 1.61s
# 775:	learn: 0.4271710	total: 5.56s	remaining: 1.6s
# 776:	learn: 0.4269616	total: 5.56s	remaining: 1.6s
# 777:	learn: 0.4264567	total: 5.57s	remaining: 1.59s
# 778:	learn: 0.4261094	total: 5.58s	remaining: 1.58s
# 779:	learn: 0.4256099	total: 5.58s	remaining: 1.57s
# 780:	learn: 0.4253372	total: 5.59s	remaining: 1.57s
# 781:	learn: 0.4251512	total: 5.59s	remaining: 1.56s
# 782:	learn: 0.4246748	total: 5.6s	remaining: 1.55s
# 783:	learn: 0.4243094	total: 5.61s	remaining: 1.54s
# 784:	learn: 0.4239394	total: 5.62s	remaining: 1.54s
# 785:	learn: 0.4235644	total: 5.62s	remaining: 1.53s
# 786:	learn: 0.4232142	total: 5.63s	remaining: 1.52s
# 787:	learn: 0.4228305	total: 5.63s	remaining: 1.52s
# 788:	learn: 0.4223765	total: 5.64s	remaining: 1.51s
# 789:	learn: 0.4221344	total: 5.65s	remaining: 1.5s
# 790:	learn: 0.4217474	total: 5.65s	remaining: 1.49s
# 791:	learn: 0.4214997	total: 5.66s	remaining: 1.49s
# 792:	learn: 0.4209722	total: 5.67s	remaining: 1.48s
# 793:	learn: 0.4204024	total: 5.67s	remaining: 1.47s
# 794:	learn: 0.4199776	total: 5.68s	remaining: 1.46s
# 795:	learn: 0.4194556	total: 5.69s	remaining: 1.46s
# 796:	learn: 0.4190712	total: 5.7s	remaining: 1.45s
# 797:	learn: 0.4187654	total: 5.7s	remaining: 1.44s
# 798:	learn: 0.4185339	total: 5.71s	remaining: 1.44s
# 799:	learn: 0.4178532	total: 5.71s	remaining: 1.43s
# 800:	learn: 0.4176263	total: 5.72s	remaining: 1.42s
# 801:	learn: 0.4172571	total: 5.73s	remaining: 1.41s
# 802:	learn: 0.4170395	total: 5.73s	remaining: 1.41s
# 803:	learn: 0.4167022	total: 5.73s	remaining: 1.4s
# 804:	learn: 0.4164211	total: 5.74s	remaining: 1.39s
# 805:	learn: 0.4159871	total: 5.75s	remaining: 1.38s
# 806:	learn: 0.4156796	total: 5.75s	remaining: 1.37s
# 807:	learn: 0.4153582	total: 5.75s	remaining: 1.37s
# 808:	learn: 0.4147373	total: 5.76s	remaining: 1.36s
# 809:	learn: 0.4143642	total: 5.77s	remaining: 1.35s
# 810:	learn: 0.4139029	total: 5.78s	remaining: 1.35s
# 811:	learn: 0.4135918	total: 5.79s	remaining: 1.34s
# 812:	learn: 0.4131083	total: 5.79s	remaining: 1.33s
# 813:	learn: 0.4128931	total: 5.8s	remaining: 1.32s
# 814:	learn: 0.4125724	total: 5.81s	remaining: 1.32s
# 815:	learn: 0.4121362	total: 5.81s	remaining: 1.31s
# 816:	learn: 0.4115624	total: 5.82s	remaining: 1.3s
# 817:	learn: 0.4109758	total: 5.82s	remaining: 1.29s
# 818:	learn: 0.4107675	total: 5.83s	remaining: 1.29s
# 819:	learn: 0.4105929	total: 5.84s	remaining: 1.28s
# 820:	learn: 0.4101013	total: 5.85s	remaining: 1.28s
# 821:	learn: 0.4097744	total: 5.86s	remaining: 1.27s
# 822:	learn: 0.4095363	total: 5.87s	remaining: 1.26s
# 823:	learn: 0.4091048	total: 5.87s	remaining: 1.25s
# 824:	learn: 0.4087479	total: 5.89s	remaining: 1.25s
# 825:	learn: 0.4084324	total: 5.91s	remaining: 1.24s
# 826:	learn: 0.4078376	total: 5.91s	remaining: 1.24s
# 827:	learn: 0.4075052	total: 5.92s	remaining: 1.23s
# 828:	learn: 0.4071152	total: 5.93s	remaining: 1.22s
# 829:	learn: 0.4066741	total: 5.94s	remaining: 1.22s
# 830:	learn: 0.4062735	total: 5.94s	remaining: 1.21s
# 831:	learn: 0.4056358	total: 5.95s	remaining: 1.2s
# 832:	learn: 0.4053162	total: 5.95s	remaining: 1.19s
# 833:	learn: 0.4050376	total: 5.96s	remaining: 1.19s
# 834:	learn: 0.4046348	total: 5.97s	remaining: 1.18s
# 835:	learn: 0.4041745	total: 5.99s	remaining: 1.17s
# 836:	learn: 0.4037958	total: 6.01s	remaining: 1.17s
# 837:	learn: 0.4034021	total: 6.02s	remaining: 1.16s
# 838:	learn: 0.4029680	total: 6.03s	remaining: 1.16s
# 839:	learn: 0.4026540	total: 6.05s	remaining: 1.15s
# 840:	learn: 0.4022754	total: 6.06s	remaining: 1.15s
# 841:	learn: 0.4016770	total: 6.07s	remaining: 1.14s
# 842:	learn: 0.4012591	total: 6.08s	remaining: 1.13s
# 843:	learn: 0.4006903	total: 6.09s	remaining: 1.13s
# 844:	learn: 0.4002023	total: 6.09s	remaining: 1.12s
# 845:	learn: 0.3997486	total: 6.1s	remaining: 1.11s
# 846:	learn: 0.3992929	total: 6.11s	remaining: 1.1s
# 847:	learn: 0.3990150	total: 6.12s	remaining: 1.1s
# 848:	learn: 0.3987393	total: 6.12s	remaining: 1.09s
# 849:	learn: 0.3983223	total: 6.13s	remaining: 1.08s
# 850:	learn: 0.3978605	total: 6.14s	remaining: 1.07s
# 851:	learn: 0.3973392	total: 6.16s	remaining: 1.07s
# 852:	learn: 0.3969761	total: 6.17s	remaining: 1.06s
# 853:	learn: 0.3967867	total: 6.18s	remaining: 1.05s
# 854:	learn: 0.3964063	total: 6.19s	remaining: 1.05s
# 855:	learn: 0.3959431	total: 6.21s	remaining: 1.04s
# 856:	learn: 0.3955375	total: 6.22s	remaining: 1.04s
# 857:	learn: 0.3953519	total: 6.22s	remaining: 1.03s
# 858:	learn: 0.3948444	total: 6.23s	remaining: 1.02s
# 859:	learn: 0.3945158	total: 6.24s	remaining: 1.01s
# 860:	learn: 0.3942620	total: 6.24s	remaining: 1.01s
# 861:	learn: 0.3938923	total: 6.25s	remaining: 1s
# 862:	learn: 0.3935592	total: 6.26s	remaining: 993ms
# 863:	learn: 0.3930566	total: 6.27s	remaining: 986ms
# 864:	learn: 0.3927858	total: 6.27s	remaining: 979ms
# 865:	learn: 0.3923869	total: 6.28s	remaining: 972ms
# 866:	learn: 0.3920364	total: 6.29s	remaining: 964ms
# 867:	learn: 0.3917113	total: 6.29s	remaining: 957ms
# 868:	learn: 0.3914854	total: 6.3s	remaining: 950ms
# 869:	learn: 0.3913268	total: 6.31s	remaining: 943ms
# 870:	learn: 0.3908970	total: 6.32s	remaining: 935ms
# 871:	learn: 0.3905478	total: 6.32s	remaining: 928ms
# 872:	learn: 0.3902481	total: 6.33s	remaining: 921ms
# 873:	learn: 0.3900969	total: 6.33s	remaining: 913ms
# 874:	learn: 0.3896783	total: 6.34s	remaining: 905ms
# 875:	learn: 0.3894501	total: 6.35s	remaining: 898ms
# 876:	learn: 0.3889943	total: 6.37s	remaining: 893ms
# 877:	learn: 0.3886536	total: 6.38s	remaining: 886ms
# 878:	learn: 0.3882648	total: 6.39s	remaining: 880ms
# 879:	learn: 0.3877135	total: 6.4s	remaining: 873ms
# 880:	learn: 0.3874127	total: 6.41s	remaining: 866ms
# 881:	learn: 0.3868870	total: 6.41s	remaining: 858ms
# 882:	learn: 0.3865143	total: 6.42s	remaining: 851ms
# 883:	learn: 0.3861904	total: 6.43s	remaining: 844ms
# 884:	learn: 0.3856366	total: 6.43s	remaining: 836ms
# 885:	learn: 0.3852631	total: 6.44s	remaining: 829ms
# 886:	learn: 0.3850318	total: 6.45s	remaining: 822ms
# 887:	learn: 0.3847072	total: 6.46s	remaining: 815ms
# 888:	learn: 0.3844078	total: 6.47s	remaining: 807ms
# 889:	learn: 0.3841955	total: 6.48s	remaining: 801ms
# 890:	learn: 0.3837964	total: 6.5s	remaining: 795ms
# 891:	learn: 0.3835098	total: 6.51s	remaining: 789ms
# 892:	learn: 0.3833323	total: 6.52s	remaining: 781ms
# 893:	learn: 0.3830226	total: 6.53s	remaining: 774ms
# 894:	learn: 0.3827792	total: 6.54s	remaining: 767ms
# 895:	learn: 0.3825431	total: 6.54s	remaining: 759ms
# 896:	learn: 0.3821526	total: 6.55s	remaining: 752ms
# 897:	learn: 0.3817895	total: 6.56s	remaining: 745ms
# 898:	learn: 0.3813241	total: 6.57s	remaining: 738ms
# 899:	learn: 0.3809514	total: 6.57s	remaining: 730ms
# 900:	learn: 0.3807884	total: 6.58s	remaining: 723ms
# 901:	learn: 0.3805179	total: 6.59s	remaining: 716ms
# 902:	learn: 0.3802254	total: 6.59s	remaining: 708ms
# 903:	learn: 0.3799262	total: 6.6s	remaining: 701ms
# 904:	learn: 0.3796255	total: 6.61s	remaining: 694ms
# 905:	learn: 0.3793180	total: 6.62s	remaining: 687ms
# 906:	learn: 0.3787509	total: 6.62s	remaining: 679ms
# 907:	learn: 0.3782834	total: 6.62s	remaining: 671ms
# 908:	learn: 0.3780539	total: 6.63s	remaining: 664ms
# 909:	learn: 0.3778687	total: 6.64s	remaining: 657ms
# 910:	learn: 0.3776443	total: 6.65s	remaining: 650ms
# 911:	learn: 0.3774328	total: 6.65s	remaining: 642ms
# 912:	learn: 0.3770279	total: 6.66s	remaining: 634ms
# 913:	learn: 0.3767920	total: 6.67s	remaining: 627ms
# 914:	learn: 0.3765389	total: 6.67s	remaining: 620ms
# 915:	learn: 0.3762824	total: 6.67s	remaining: 612ms
# 916:	learn: 0.3757554	total: 6.68s	remaining: 605ms
# 917:	learn: 0.3752938	total: 6.69s	remaining: 597ms
# 918:	learn: 0.3749472	total: 6.7s	remaining: 590ms
# 919:	learn: 0.3744424	total: 6.7s	remaining: 583ms
# 920:	learn: 0.3741049	total: 6.71s	remaining: 576ms
# 921:	learn: 0.3736643	total: 6.71s	remaining: 568ms
# 922:	learn: 0.3733955	total: 6.72s	remaining: 561ms
# 923:	learn: 0.3729689	total: 6.73s	remaining: 554ms
# 924:	learn: 0.3726182	total: 6.74s	remaining: 546ms
# 925:	learn: 0.3723152	total: 6.74s	remaining: 539ms
# 926:	learn: 0.3720076	total: 6.75s	remaining: 531ms
# 927:	learn: 0.3716301	total: 6.75s	remaining: 524ms
# 928:	learn: 0.3712607	total: 6.77s	remaining: 517ms
# 929:	learn: 0.3709783	total: 6.78s	remaining: 510ms
# 930:	learn: 0.3707015	total: 6.79s	remaining: 503ms
# 931:	learn: 0.3704905	total: 6.8s	remaining: 496ms
# 932:	learn: 0.3701343	total: 6.8s	remaining: 489ms
# 933:	learn: 0.3698115	total: 6.81s	remaining: 481ms
# 934:	learn: 0.3693432	total: 6.82s	remaining: 474ms
# 935:	learn: 0.3690427	total: 6.83s	remaining: 467ms
# 936:	learn: 0.3685986	total: 6.84s	remaining: 460ms
# 937:	learn: 0.3683329	total: 6.84s	remaining: 452ms
# 938:	learn: 0.3680531	total: 6.86s	remaining: 445ms
# 939:	learn: 0.3676863	total: 6.87s	remaining: 438ms
# 940:	learn: 0.3673200	total: 6.88s	remaining: 431ms
# 941:	learn: 0.3668684	total: 6.89s	remaining: 424ms
# 942:	learn: 0.3666608	total: 6.89s	remaining: 417ms
# 943:	learn: 0.3663928	total: 6.9s	remaining: 410ms
# 944:	learn: 0.3660946	total: 6.92s	remaining: 403ms
# 945:	learn: 0.3655455	total: 6.93s	remaining: 395ms
# 946:	learn: 0.3651260	total: 6.94s	remaining: 388ms
# 947:	learn: 0.3646655	total: 6.94s	remaining: 381ms
# 948:	learn: 0.3643370	total: 6.96s	remaining: 374ms
# 949:	learn: 0.3639823	total: 6.99s	remaining: 368ms
# 950:	learn: 0.3635772	total: 7.01s	remaining: 361ms
# 951:	learn: 0.3632383	total: 7.04s	remaining: 355ms
# 952:	learn: 0.3628406	total: 7.05s	remaining: 348ms
# 953:	learn: 0.3624606	total: 7.07s	remaining: 341ms
# 954:	learn: 0.3621165	total: 7.08s	remaining: 334ms
# 955:	learn: 0.3615486	total: 7.1s	remaining: 327ms
# 956:	learn: 0.3613413	total: 7.11s	remaining: 319ms
# 957:	learn: 0.3609171	total: 7.12s	remaining: 312ms
# 958:	learn: 0.3606214	total: 7.13s	remaining: 305ms
# 959:	learn: 0.3602543	total: 7.14s	remaining: 298ms
# 960:	learn: 0.3600810	total: 7.16s	remaining: 290ms
# 961:	learn: 0.3598478	total: 7.17s	remaining: 283ms
# 962:	learn: 0.3593133	total: 7.18s	remaining: 276ms
# 963:	learn: 0.3591213	total: 7.2s	remaining: 269ms
# 964:	learn: 0.3587687	total: 7.21s	remaining: 262ms
# 965:	learn: 0.3581992	total: 7.22s	remaining: 254ms
# 966:	learn: 0.3579006	total: 7.23s	remaining: 247ms
# 967:	learn: 0.3574162	total: 7.23s	remaining: 239ms
# 968:	learn: 0.3569514	total: 7.25s	remaining: 232ms
# 969:	learn: 0.3564560	total: 7.26s	remaining: 224ms
# 970:	learn: 0.3561003	total: 7.26s	remaining: 217ms
# 971:	learn: 0.3556658	total: 7.27s	remaining: 209ms
# 972:	learn: 0.3552744	total: 7.28s	remaining: 202ms
# 973:	learn: 0.3549592	total: 7.29s	remaining: 195ms
# 974:	learn: 0.3545225	total: 7.3s	remaining: 187ms
# 975:	learn: 0.3542329	total: 7.32s	remaining: 180ms
# 976:	learn: 0.3539923	total: 7.34s	remaining: 173ms
# 977:	learn: 0.3538026	total: 7.35s	remaining: 165ms
# 978:	learn: 0.3534981	total: 7.37s	remaining: 158ms
# 979:	learn: 0.3531951	total: 7.39s	remaining: 151ms
# 980:	learn: 0.3529862	total: 7.41s	remaining: 144ms
# 981:	learn: 0.3526712	total: 7.44s	remaining: 136ms
# 982:	learn: 0.3522055	total: 7.47s	remaining: 129ms
# 983:	learn: 0.3517158	total: 7.48s	remaining: 122ms
# 984:	learn: 0.3514971	total: 7.5s	remaining: 114ms
# 985:	learn: 0.3510212	total: 7.52s	remaining: 107ms
# 986:	learn: 0.3507138	total: 7.53s	remaining: 99.2ms
# 987:	learn: 0.3505314	total: 7.55s	remaining: 91.7ms
# 988:	learn: 0.3501619	total: 7.56s	remaining: 84.1ms
# 989:	learn: 0.3499454	total: 7.58s	remaining: 76.6ms
# 990:	learn: 0.3496837	total: 7.59s	remaining: 69ms
# 991:	learn: 0.3493672	total: 7.6s	remaining: 61.3ms
# 992:	learn: 0.3489804	total: 7.61s	remaining: 53.7ms
# 993:	learn: 0.3488284	total: 7.63s	remaining: 46ms
# 994:	learn: 0.3486336	total: 7.64s	remaining: 38.4ms
# 995:	learn: 0.3482174	total: 7.65s	remaining: 30.7ms
# 996:	learn: 0.3479047	total: 7.66s	remaining: 23ms
# 997:	learn: 0.3475510	total: 7.67s	remaining: 15.4ms
# 998:	learn: 0.3473176	total: 7.68s	remaining: 7.68ms
# 999:	learn: 0.3470126	total: 7.69s	remaining: 0us

# %%
y_test_pred = cat_class.predict(X_test)
print(accuracy_score(y_test, y_test_pred))
print(confusion_matrix(y_test, y_test_pred))
print(classification_report(y_test, y_test_pred, digits=4))
# Out:
# 0.41809925397340253
# [[369 188 256]
#  [283 292 422]
#  [221 424 628]]
#               precision    recall  f1-score   support
#
#            1     0.4227    0.4539    0.4377       813
#            2     0.3230    0.2929    0.3072       997
#            3     0.4809    0.4933    0.4870      1273
#
#     accuracy                         0.4181      3083
#    macro avg     0.4088    0.4134    0.4106      3083
# weighted avg     0.4145    0.4181    0.4159      3083

# %%
X_train.to_csv('X_train_feat.csv', index=False)
y_train.to_csv('y_train_feat.csv', index=False)
X_test.to_csv('X_test_feat.csv', index=False)
y_test.to_csv('y_test_feat.csv', index=False)

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (3643, 12)
# (3643, 1)
# (3083, 12)
# (3083, 1)

# %%
print(X_train.columns)
# Out:
# Index(['AccX', 'AccY', 'AccZ', 'GyroX', 'GyroY', 'GyroZ', 'AccMagnitude',
#        'GyroMagnitude', 'JerkX', 'JerkY', 'JerkZ', 'JerkMagnitude'],
#       dtype='object')

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.ensemble import VotingClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier

# 개별 모델 초기화
xgb_clf = XGBClassifier(use_label_encoder=False, eval_metric='mlogloss', random_state=42)
lgbm_clf = LGBMClassifier(random_state=42)
catboost_clf = CatBoostClassifier(verbose=0, random_state=42)

# Voting Classifier 설정 (Soft Voting)
voting_clf = VotingClassifier(estimators=[
    ('xgb', xgb_clf),
    ('lgbm', lgbm_clf),
    ('catboost', catboost_clf)
], voting='soft')

# 모델 학습
voting_clf.fit(X_train, y_train)

# 예측 수행
y_test_pred = voting_clf.predict(X_test)

# 정확도 출력
accuracy = accuracy_score(y_test, y_test_pred)
print(f"Ensemble 모델의 정확도: {accuracy:.2f}")
# Out:
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:98: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Ensemble 모델의 정확도: 0.44

# %%
print(accuracy_score(y_test, y_test_pred))
print(confusion_matrix(y_test, y_test_pred))
print(classification_report(y_test, y_test_pred, digits=4))
# Out:
# 0.4398313331170937
# [[368 189 256]
#  [256 330 411]
#  [212 403 658]]
#               precision    recall  f1-score   support
#
#            1     0.4402    0.4526    0.4463       813
#            2     0.3579    0.3310    0.3439       997
#            3     0.4966    0.5169    0.5065      1273
#
#     accuracy                         0.4398      3083
#    macro avg     0.4316    0.4335    0.4323      3083
# weighted avg     0.4369    0.4398    0.4381      3083

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.ensemble import VotingClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier

# 개별 모델 초기화
xgb_clf = XGBClassifier(use_label_encoder=False, eval_metric='mlogloss', random_state=42)
lgbm_clf = LGBMClassifier(random_state=42)
catboost_clf = CatBoostClassifier(verbose=0, random_state=42)

# Voting Classifier 설정 (Soft Voting)
voting_clf = VotingClassifier(estimators=[
    ('xgb', xgb_clf),
    ('lgbm', lgbm_clf),
    # ('catboost', catboost_clf)
], voting='soft')

# 모델 학습
voting_clf.fit(X_train, y_train)

# 예측 수행
y_test_pred = voting_clf.predict(X_test)

# 정확도 출력
accuracy = accuracy_score(y_test, y_test_pred)
print(f"Ensemble 모델의 정확도: {accuracy:.2f}")
print(accuracy_score(y_test, y_test_pred))
print(confusion_matrix(y_test, y_test_pred))
print(classification_report(y_test, y_test_pred, digits=4))
# Out:
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:98: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Ensemble 모델의 정확도: 0.44
# 0.4369120986052546
# [[370 198 245]
#  [270 300 427]
#  [212 384 677]]
#               precision    recall  f1-score   support
#
#            1     0.4343    0.4551    0.4444       813
#            2     0.3401    0.3009    0.3193       997
#            3     0.5019    0.5318    0.5164      1273
#
#     accuracy                         0.4369      3083
#    macro avg     0.4254    0.4293    0.4267      3083
# weighted avg     0.4317    0.4369    0.4337      3083

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.ensemble import VotingClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier

# 개별 모델 초기화
xgb_clf = XGBClassifier(use_label_encoder=False, eval_metric='mlogloss', random_state=42)
lgbm_clf = LGBMClassifier(random_state=42)
catboost_clf = CatBoostClassifier(verbose=0, random_state=42)

# Voting Classifier 설정 (Soft Voting)
voting_clf = VotingClassifier(estimators=[
    # ('xgb', xgb_clf),
    ('lgbm', lgbm_clf),
    ('catboost', catboost_clf)
], voting='soft')

# 모델 학습
voting_clf.fit(X_train, y_train)

# 예측 수행
y_test_pred = voting_clf.predict(X_test)

# 정확도 출력
accuracy = accuracy_score(y_test, y_test_pred)
print(f"Ensemble 모델의 정확도: {accuracy:.2f}")
print(accuracy_score(y_test, y_test_pred))
print(confusion_matrix(y_test, y_test_pred))
print(classification_report(y_test, y_test_pred, digits=4))
# Out:
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:98: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Ensemble 모델의 정확도: 0.44
# 0.4375608173856633
# [[381 188 244]
#  [269 317 411]
#  [212 410 651]]
#               precision    recall  f1-score   support
#
#            1     0.4420    0.4686    0.4549       813
#            2     0.3464    0.3180    0.3316       997
#            3     0.4985    0.5114    0.5048      1273
#
#     accuracy                         0.4376      3083
#    macro avg     0.4290    0.4327    0.4305      3083
# weighted avg     0.4344    0.4376    0.4357      3083

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.ensemble import VotingClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier

# 개별 모델 초기화
xgb_clf = XGBClassifier(use_label_encoder=False, eval_metric='mlogloss', random_state=42)
lgbm_clf = LGBMClassifier(random_state=42)
catboost_clf = CatBoostClassifier(verbose=0, random_state=42)

# Voting Classifier 설정 (Soft Voting)
voting_clf = VotingClassifier(estimators=[
    ('xgb', xgb_clf),
    # ('lgbm', lgbm_clf),
    ('catboost', catboost_clf)
], voting='soft')

# 모델 학습
voting_clf.fit(X_train, y_train)

# 예측 수행
y_test_pred = voting_clf.predict(X_test)

# 정확도 출력
accuracy = accuracy_score(y_test, y_test_pred)
print(f"Ensemble 모델의 정확도: {accuracy:.2f}")
print(accuracy_score(y_test, y_test_pred))
print(confusion_matrix(y_test, y_test_pred))
print(classification_report(y_test, y_test_pred, digits=4))
# Out:
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:98: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Ensemble 모델의 정확도: 0.43
# 0.43399286409341553
# [[371 192 250]
#  [265 321 411]
#  [218 409 646]]
#               precision    recall  f1-score   support
#
#            1     0.4344    0.4563    0.4451       813
#            2     0.3482    0.3220    0.3345       997
#            3     0.4943    0.5075    0.5008      1273
#
#     accuracy                         0.4340      3083
#    macro avg     0.4256    0.4286    0.4268      3083
# weighted avg     0.4312    0.4340    0.4323      3083

# %%
# !pip install optuna

# %%
import optuna
import lightgbm as lgb
import pandas as pd
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import accuracy_score

# %%
# Objective 함수 정의
def objective(trial):
    param = {
        'objective': 'multiclass',
        'metric': 'multi_logloss',
        'verbosity': -1,
        'boosting_type': 'gbdt',
        'num_class': 3,  # 클래스 개수
        'max_depth': trial.suggest_int('max_depth', 4, 10),
        'num_leaves': trial.suggest_int('num_leaves', 20, 150),
        'learning_rate': trial.suggest_loguniform('learning_rate', 1e-3, 1e-1),
        'n_estimators': trial.suggest_int('n_estimators', 100, 1000),
        'min_child_samples': trial.suggest_int('min_child_samples', 5, 30),
        'subsample': trial.suggest_float('subsample', 0.5, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1.0),
        'reg_alpha': trial.suggest_loguniform('reg_alpha', 1e-8, 1.0),
        'reg_lambda': trial.suggest_loguniform('reg_lambda', 1e-8, 1.0)
    }

    model = lgb.LGBMClassifier(**param)
    return cross_val_score(model, X_train, y_train, cv=5, scoring='accuracy').mean()

# %%
# Optuna를 사용한 하이퍼파라미터 튜닝
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=100)

# 최적의 하이퍼파라미터 출력
print("최적의 하이퍼파라미터:")
print(study.best_params)
# Out:
# [I 2024-07-02 18:21:00,848] A new study created in memory with name: no-name-205f80fd-d3fb-43c0-a2b1-90052498fa6f
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\ipykernel_launcher.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   # This is added back by InteractiveShellApp.init_path()
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\ipykernel_launcher.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   app.launch_new_instance()
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\ipykernel_launcher.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:98: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:98: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:98: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:98: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:98: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-07-02 18:21:03,879] Trial 0 finished with value: 0.4276715054492833 and parameters: {'max_depth': 4, 'num_leaves': 78, 'learning_rate': 0.023702506371271897, 'n_estimators': 578, 'min_child_samples': 13, 'subsample': 0.8519496718594332, 'colsample_bytree': 0.5036149421606935, 'reg_alpha': 2.958444178327852e-05, 'reg_lambda': 2.6293517841606763e-08}. Best is trial 0 with value: 0.4276715054492833.
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\ipykernel_launcher.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   # This is added back by InteractiveShellApp.init_path()
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\ipykernel_launcher.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   app.launch_new_instance()
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\ipykernel_launcher.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:98: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:98: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:98: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:98: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:98: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-07-02 18:21:09,170] Trial 1 finished with value: 0.4246544265062783 and parameters: {'max_depth': 8, 'num_leaves': 97, 'learning_rate': 0.06365885789939177, 'n_estimators': 328, 'min_child_samples': 23, 'subsample': 0.9955952507697345, 'colsample_bytree': 0.9078211824365108, 'reg_alpha': 2.8352350763933263e-06, 'reg_lambda': 0.2703821862840098}. Best is trial 0 with value: 0.4276715054492833.
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\ipykernel_launcher.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   # This is added back by InteractiveShellApp.init_path()
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\ipykernel_launcher.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   app.launch_new_instance()
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\ipykernel_launcher.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:98: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:98: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:98: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:98: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:98: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-07-02 18:21:20,536] Trial 2 finished with value: 0.42574805167397767 and parameters: {'max_depth': 6, 'num_leaves': 38, 'learning_rate': 0.016842274875481802, 'n_estimators': 990, 'min_child_samples': 9, 'subsample': 0.8817579755296883, 'colsample_bytree': 0.5356576869347649, 'reg_alpha': 5.9345038687543656e-05, 'reg_lambda': 0.051399797186671134}. Best is trial 0 with value: 0.4276715054492833.
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\ipykernel_launcher.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   # This is added back by InteractiveShellApp.init_path()
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\ipykernel_launcher.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   app.launch_new_instance()
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\ipykernel_launcher.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:98: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:98: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:98: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:98: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:98: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-07-02 18:21:33,008] Trial 3 finished with value: 0.428495681273459 and parameters: {'max_depth': 10, 'num_leaves': 113, 'learning_rate': 0.014671848435551353, 'n_estimators': 631, 'min_child_samples': 16, 'subsample': 0.7031441886427325, 'colsample_bytree': 0.6294302290926161, 'reg_alpha': 0.0006533557569182027, 'reg_lambda': 0.04147427714124403}. Best is trial 3 with value: 0.428495681273459.
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\ipykernel_launcher.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   # This is added back by InteractiveShellApp.init_path()
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\ipykernel_launcher.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   app.launch_new_instance()
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\ipykernel_launcher.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:98: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:98: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:98: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:98: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:98: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-07-02 18:21:36,139] Trial 4 finished with value: 0.4279515066552103 and parameters: {'max_depth': 4, 'num_leaves': 63, 'learning_rate': 0.0013891974564651025, 'n_estimators': 856, 'min_child_samples': 21, 'subsample': 0.5564832712060541, 'colsample_bytree': 0.5974403244781306, 'reg_alpha': 2.3770723984001372e-05, 'reg_lambda': 1.0653457647419381e-07}. Best is trial 3 with value: 0.428495681273459.
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\ipykernel_launcher.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   # This is added back by InteractiveShellApp.init_path()
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\ipykernel_launcher.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   app.launch_new_instance()
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\ipykernel_launcher.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:98: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:98: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:98: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:98: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:98: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-07-02 18:21:38,780] Trial 5 finished with value: 0.42712770768326325 and parameters: {'max_depth': 5, 'num_leaves': 149, 'learning_rate': 0.00293298180225412, 'n_estimators': 410, 'min_child_samples': 9, 'subsample': 0.5485695655109304, 'colsample_bytree': 0.7618297637972833, 'reg_alpha': 0.41666657114252076, 'reg_lambda': 4.177707259868486e-06}. Best is trial 3 with value: 0.428495681273459.
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\ipykernel_launcher.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   # This is added back by InteractiveShellApp.init_path()
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\ipykernel_launcher.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   app.launch_new_instance()
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\ipykernel_launcher.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:98: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:98: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:98: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:98: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:98: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-07-02 18:21:48,223] Trial 6 finished with value: 0.4279473612806946 and parameters: {'max_depth': 8, 'num_leaves': 55, 'learning_rate': 0.028569441463919924, 'n_estimators': 746, 'min_child_samples': 16, 'subsample': 0.5307653429779927, 'colsample_bytree': 0.9311503086054227, 'reg_alpha': 0.04354657569794192, 'reg_lambda': 8.800211937688635e-07}. Best is trial 3 with value: 0.428495681273459.
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\ipykernel_launcher.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   # This is added back by InteractiveShellApp.init_path()
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\ipykernel_launcher.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   app.launch_new_instance()
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\ipykernel_launcher.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:98: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:98: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:98: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:98: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:98: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-07-02 18:21:49,603] Trial 7 finished with value: 0.43014704773964035 and parameters: {'max_depth': 5, 'num_leaves': 121, 'learning_rate': 0.008447129846355745, 'n_estimators': 221, 'min_child_samples': 9, 'subsample': 0.8452690320300813, 'colsample_bytree': 0.766999599588003, 'reg_alpha': 7.058343881668e-07, 'reg_lambda': 1.4062094171649151e-06}. Best is trial 7 with value: 0.43014704773964035.
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\ipykernel_launcher.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   # This is added back by InteractiveShellApp.init_path()
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\ipykernel_launcher.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   app.launch_new_instance()
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\ipykernel_launcher.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:98: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:98: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:98: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:98: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:98: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-07-02 18:21:51,782] Trial 8 finished with value: 0.43151389077315 and parameters: {'max_depth': 6, 'num_leaves': 149, 'learning_rate': 0.014655646575987644, 'n_estimators': 347, 'min_child_samples': 29, 'subsample': 0.7644723485383521, 'colsample_bytree': 0.9274055798287826, 'reg_alpha': 2.1615523205236636e-08, 'reg_lambda': 4.1961955283015536e-08}. Best is trial 8 with value: 0.43151389077315.
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\ipykernel_launcher.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   # This is added back by InteractiveShellApp.init_path()
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\ipykernel_launcher.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   app.launch_new_instance()
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\ipykernel_launcher.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:98: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:98: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:98: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:98: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:98: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-07-02 18:21:55,525] Trial 9 finished with value: 0.42273700236663203 and parameters: {'max_depth': 5, 'num_leaves': 145, 'learning_rate': 0.0016736457940850216, 'n_estimators': 598, 'min_child_samples': 14, 'subsample': 0.8452889398793189, 'colsample_bytree': 0.9922845950354999, 'reg_alpha': 0.018224539240668896, 'reg_lambda': 0.002768980720626684}. Best is trial 8 with value: 0.43151389077315.
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\ipykernel_launcher.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   # This is added back by InteractiveShellApp.init_path()
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\ipykernel_launcher.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   app.launch_new_instance()
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\ipykernel_launcher.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:98: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:98: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:98: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:98: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:98: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-07-02 18:21:56,671] Trial 10 finished with value: 0.43179351512684844 and parameters: {'max_depth': 7, 'num_leaves': 129, 'learning_rate': 0.09991657669090265, 'n_estimators': 146, 'min_child_samples': 28, 'subsample': 0.6850358401331745, 'colsample_bytree': 0.8223749305675104, 'reg_alpha': 1.2040567475279632e-08, 'reg_lambda': 0.00010467997779285256}. Best is trial 10 with value: 0.43179351512684844.
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\ipykernel_launcher.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   # This is added back by InteractiveShellApp.init_path()
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\ipykernel_launcher.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   app.launch_new_instance()
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\ipykernel_launcher.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:98: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:98: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:98: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:98: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:98: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-07-02 18:29:31,823] Trial 96 finished with value: 0.4402983162242421 and parameters: {'max_depth': 10, 'num_leaves': 129, 'learning_rate': 0.008257995161158735, 'n_estimators': 579, 'min_child_samples': 28, 'subsample': 0.5315574854200462, 'colsample_bytree': 0.5756031835541081, 'reg_alpha': 5.076306246885321e-07, 'reg_lambda': 0.0038678877477120975}. Best is trial 96 with value: 0.4402983162242421.
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\ipykernel_launcher.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   # This is added back by InteractiveShellApp.init_path()
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\ipykernel_launcher.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   app.launch_new_instance()
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\ipykernel_launcher.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:98: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:98: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:98: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:98: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:98: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-07-02 18:29:36,963] Trial 97 finished with value: 0.43672914876618585 and parameters: {'max_depth': 10, 'num_leaves': 135, 'learning_rate': 0.008180208836822375, 'n_estimators': 414, 'min_child_samples': 26, 'subsample': 0.5394626787228666, 'colsample_bytree': 0.5844493505015456, 'reg_alpha': 1.4674103344006162e-06, 'reg_lambda': 0.004457303779125403}. Best is trial 96 with value: 0.4402983162242421.
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\ipykernel_launcher.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   # This is added back by InteractiveShellApp.init_path()
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\ipykernel_launcher.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   app.launch_new_instance()
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\ipykernel_launcher.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:98: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:98: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:98: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:98: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:98: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-07-02 18:29:45,459] Trial 98 finished with value: 0.43563175507619956 and parameters: {'max_depth': 10, 'num_leaves': 145, 'learning_rate': 0.00940833658892548, 'n_estimators': 612, 'min_child_samples': 28, 'subsample': 0.5919407639293293, 'colsample_bytree': 0.5639969162887701, 'reg_alpha': 3.83021801448676e-06, 'reg_lambda': 0.0014313977545171782}. Best is trial 96 with value: 0.4402983162242421.
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\ipykernel_launcher.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   # This is added back by InteractiveShellApp.init_path()
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\ipykernel_launcher.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   app.launch_new_instance()
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\ipykernel_launcher.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:98: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:98: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:98: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:98: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:98: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-07-02 18:29:55,997] Trial 99 finished with value: 0.42986553912479836 and parameters: {'max_depth': 10, 'num_leaves': 134, 'learning_rate': 0.011116570982141206, 'n_estimators': 470, 'min_child_samples': 12, 'subsample': 0.5092116369424007, 'colsample_bytree': 0.6825725957877324, 'reg_alpha': 6.064632367365423e-07, 'reg_lambda': 0.01892329148620444}. Best is trial 96 with value: 0.4402983162242421.
# 최적의 하이퍼파라미터:
# {'max_depth': 10, 'num_leaves': 129, 'learning_rate': 0.008257995161158735, 'n_estimators': 579, 'min_child_samples': 28, 'subsample': 0.5315574854200462, 'colsample_bytree': 0.5756031835541081, 'reg_alpha': 5.076306246885321e-07, 'reg_lambda': 0.0038678877477120975}

# %%
# 최적의 하이퍼파라미터로 모델 구축
best_params = study.best_params
best_model = lgb.LGBMClassifier(**best_params)
best_model.fit(X_train, y_train)
# Out:
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:98: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\MILAB\Anaconda3\envs\torchpy37\lib\site-packages\sklearn\preprocessing\_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LGBMClassifier(colsample_bytree=0.5756031835541081,
#                learning_rate=0.008257995161158735, max_depth=10,
#                min_child_samples=28, n_estimators=579, num_leaves=129,
#                reg_alpha=5.076306246885321e-07,
#                reg_lambda=0.0038678877477120975, subsample=0.5315574854200462)

# %%
y_test_pred = best_model.predict(X_test)
print(accuracy_score(y_test, y_test_pred))
print(confusion_matrix(y_test, y_test_pred))
print(classification_report(y_test, y_test_pred, digits=4))
# Out:
# 0.4459941615309763
# [[371 173 269]
#  [252 281 464]
#  [192 358 723]]
#               precision    recall  f1-score   support
#
#            1     0.4552    0.4563    0.4558       813
#            2     0.3461    0.2818    0.3107       997
#            3     0.4966    0.5679    0.5299      1273
#
#     accuracy                         0.4460      3083
#    macro avg     0.4326    0.4354    0.4321      3083
# weighted avg     0.4370    0.4460    0.4394      3083

# %%
# from optuna import Trial, visualization                       ```

# optuna.visualization.plot_param_importances(study)
# optuna.visualization.plot_optimization_history(study)

# %%
import joblib
joblib.dump(best_model, 'lgb_best_model.pkl')
# Out:
# ['lgb_best_model.pkl']

# %%
joblib.dump(best_model, 'lgb_best_model_1.pkl')
# Out:
# ['lgb_best_model_1.pkl']

# %%
best_model.booster_.save_model('lgb_best_model_2_txt.txt')

# %%
X_train.head()
# Out:
#        AccX      AccY      AccZ     GyroX     GyroY     GyroZ  AccMagnitude  \
# 1 -1.624864 -1.082492 -0.204183 -0.028558  0.051313  0.135536      1.963075
# 2 -0.594660 -0.122410  0.220502 -0.019395 -0.029322  0.087888      0.645930
# 3  0.738478 -0.228456  0.667732  0.069791 -0.029932  0.054902      1.021474
# 4  0.101741  0.777568 -0.066730  0.030696 -0.003665  0.054902      0.787030
# 5  0.158470  0.345891  0.355274  0.021533  0.115454  0.014584      0.520551
#
#    GyroMagnitude     JerkX     JerkY     JerkZ  JerkMagnitude
# 1       0.147711 -1.624864 -1.082492 -0.204183       1.963075
# 2       0.094659  1.030204  0.960082  0.424685       1.470862
# 3       0.093707  1.333138 -0.106046  0.447230       1.410148
# 4       0.063007 -0.636737  1.006023 -0.734462       1.398911
# 5       0.118346  0.056728 -0.431676  0.422004       0.606341

# %%
X_train.describe()
# Out:
#               AccX         AccY         AccZ        GyroX        GyroY  \
# count  3643.000000  3643.000000  3643.000000  3643.000000  3643.000000
# mean      0.040478    -0.073438     0.008274     0.001577    -0.001225
# std       0.985789     0.903531     0.985196     0.066920     0.126189
# min      -4.636523    -4.699795    -7.143998    -0.751822    -1.587028
# 25%      -0.550872    -0.592600    -0.558509    -0.028558    -0.053756
# 50%       0.004032    -0.081265     0.002422     0.001985    -0.001833
# 75%       0.595994     0.452967     0.556336     0.031918     0.051313
# max       4.985548     4.245151     5.171739     0.849255     1.679879
#
#              GyroZ  AccMagnitude  GyroMagnitude        JerkX        JerkY  \
# count  3643.000000   3643.000000    3643.000000  3643.000000  3643.000000
# mean      0.007923      1.438205       0.130770    -0.000110     0.000112
# std       0.115692      0.834781       0.129414     1.072292     1.069894
# min      -1.236468      0.064935       0.003707    -5.706999    -4.541037
# 25%      -0.029398      0.852461       0.058419    -0.665565    -0.658815
# 50%       0.002978      1.268172       0.096612     0.022210    -0.013277
# 75%       0.040852      1.843373       0.157894     0.676944     0.659891
# max       1.190500      7.451246       1.957027     4.369801     6.718676
#
#              JerkZ  JerkMagnitude
# count  3643.000000    3643.000000
# mean     -0.000116       1.789139
# std       1.376684       0.993904
# min      -6.669646       0.024072
# 25%      -0.786008       1.090837
# 50%       0.006993       1.586349
# 75%       0.801045       2.258621
# max       6.639951       7.146545
